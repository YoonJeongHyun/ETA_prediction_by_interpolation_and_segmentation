# %%
import pandas as pd
import numpy as np
import cx_Oracle
import os
import json
import datetime
import warnings
import matplotlib.pyplot as plt
warnings.filterwarnings(action="ignore")
from selenium import webdriver
from selenium.webdriver.support.ui import Select
from selenium.webdriver.common.by import By
import bs4
import requests
import time
import math
import random
from shapely.geometry import Point, Polygon
import time as timesys
from pyproj import Geod
from haversine import haversine
pd.set_option('display.max_columns', None)

# %%
interpolation_number = "10000"

# %%
COSCO_FOS_voyages_list = [
    'COSCO_FOS_VRKR6_2022_20processed', 'COSCO_FOS_VRKR6_2022_23processed',
    'COSCO_FOS_VRKR6_2022_24processed', 'COSCO_FOS_VRKR6_2022_25processed',
    'COSCO_FOS_VRKR6_2022_26processed', 'COSCO_FOS_VRKR6_2022_27processed',
    'COSCO_FOS_VRKR6_2022_28processed', 'COSCO_FOS_VRKR6_2022_29processed',
    'COSCO_FOS_VRKR6_2022_30processed'
]

# %% [markdown]
# # 전항지 출항 확인

# %% [markdown]
# 전항지 출항 지점 확인

# %%
import os
 
path_dir = 'voy_path'
 
file_list = os.listdir(path_dir)
file_new_list = []
for i in file_list:
    if "portmis" in i:
        file_new_list.append(i)

# %%
# ATA 확인
def check_ATA(df_test):
    for i in df_test.index:
        LONGITUDE = df_test.loc[i, 'longitude']
        LATITUDE = df_test.loc[i, 'latitude']
        if Point(LONGITUDE, LATITUDE).within(poly_busan):    
            stop_index = i - 1
            break
            continue
    return stop_index

# %% [markdown]
# # 시각화 툴로 processed된 것들 확인

# %% [markdown]
# 항로 클러스터링

# %%
# dense_upper_china_list = ['COSCO_FOS_VRKR6_23processed'
# ,'AKA_BHUM_9V7282_7processed'
# , 'COSCO_FOS_VRKR6_25processed'
# , 'MSC_LA_SPEZIA_DIGX2_2processed'
# , 'OOCL_NEW_YORK_VRJS2_2processed'
# , 'MSC_WASHINGTON_5LDP4_4processed'
# , 'MSC_SOFIA_PAZ_D5FL9_2processed'
# , 'ZHU_CHENG_XIN_ZHOU_VRKR6_26processed'
# , 'OOCL_HAMBURG_VRZK9_6processed'
# , 'SEAMAX_STRATFORD_V7EP2_6processed'
# , 'OOCL_LUXEMBOURG_VRGO3_5processed'
# , 'ZHU_CHENG_XIN_ZHOU_VRKR6_25processed'
# , 'MSC_LUCIANA_3FTY3_4processed'
# , 'MSC_RENEE_VRPL2_5processed'
# , 'COSCO_FOS_VRKR6_24processed'
# , 'COSCO_FOS_VRKR6_20processed'
# , 'COSCO_FOS_VRKR6_26processed'
# , 'ZHU_CHENG_XIN_ZHOU_VRKR6_23processed'
# , 'OOCL_HAMBURG_VRZK9_5processed']

COSCO_FOS_voyages_list = [
    'COSCO_FOS_VRKR6_2022_20processed', 'COSCO_FOS_VRKR6_2022_23processed',
    'COSCO_FOS_VRKR6_2022_24processed', 'COSCO_FOS_VRKR6_2022_25processed',
    'COSCO_FOS_VRKR6_2022_26processed', 'COSCO_FOS_VRKR6_2022_27processed',
    'COSCO_FOS_VRKR6_2022_28processed', 'COSCO_FOS_VRKR6_2022_29processed',
    'COSCO_FOS_VRKR6_2022_30processed'
]

AKA_BHUM_voyages_list = [
    'AKA_BHUM_9V7282_2022_7processed', 'AKA_BHUM_9V7282_2022_8processed'
]
OOCL_NEW_YORK_voyages_list = [
    'OOCL_NEW_YORK_VRJS2_2022_1processed',
    'OOCL_NEW_YORK_VRJS2_2022_2processed',
    'OOCL_NEW_YORK_VRJS2_2022_3processed'
]

OOCL_LUXEMBOURG_voyages_list = [
    'OOCL_LUXEMBOURG_VRGO3_2022_5processed',
    'OOCL_LUXEMBOURG_VRGO3_2022_6processed'
]

OOCL_GENOA_voyages_list = [
    'OOCL_GENOA_VROK9_2022_3processed', 'OOCL_GENOA_VROK9_2022_5processed'
]

OOCL_HAMBURG_voyages_list = [
    'OOCL_HAMBURG_VRZK9_2022_5processed', 'OOCL_HAMBURG_VRZK9_2022_6processed'
]

SEAMAX_STRATFORD_voyages_list = [
    'SEAMAX_STRATFORD_V7EP2_2022_6processed',
    'SEAMAX_STRATFORD_V7EP2_2022_7processed'
]

ZIM_CHARLESTORN_voyages_list = [
    'ZIM_CHARLESTON_VRUC3_2022_6processed',
    'ZIM_CHARLESTON_VRUC3_2022_7processed'
]

single_voyage_list = [
    'MSC_ARIANE_3FDA3_2022_1processed', 'MSC_DANIT_3FZU8_2022_2processed',
    'MSC_EVA_3EVM7_2022_1processed', 'MSC_EXPRESS_III_A8LG7_2022_1processed',
    'MSC_KANOKO_D5TM3_2023_1processed', 'MSC_LA_SPEZIA_DIGX2_2022_2processed',
    'MSC_VANESSA_HOWD_2023_1processed', 'MSC_VIRGO_CQEB9_2023_2processed',
    'MSC_SOFIA_PAZ_D5FL9_2022_2processed',
    'MSC_WASHINGTON_5LDP4_2022_4processed',
    'MSC_RAVENNA_A8ZU8_2022_3processed', 'MSC_VANDYA_3FDW4_2022_2processed',
    'MSC_RENEE_VRPL2_2022_5processed', 'SEASPAN_OCEANIA_VRBI2_2023_1processed',
    'SEASPAN_BREEZE_VRNL8_2023_1processed', 'VALENCE_9HA3398_2023_1processed'
]

# %%
upper_china_path_dir = 'voy_path/upper_china/processed/'

# %% [markdown]
# # Tianjin to Busan PNIT

# %% [markdown]
# ## COSCO_FOS

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from shapely.geometry import LineString

# %%
from scipy import interpolate
import pandas as pd

# %% [markdown]
# ## below 3 knot 제거

# %% [markdown]
# ### interpolation 10000

# %% [markdown]
# ## low speed 항차 : 20,24, 28,29,30

# %%
result_df_dict=  {
    "experiment_no" : [],
    "mean_speed" : [],
    "max_speed" : []
}

# %%
# 가는 길인데 굳이 오래 돌아갈 필요는 없잖아 알고리즘
def optimal_next_point(current_position, shortest_point_idx, shortest_distance,
                       path_df):
    posi_c = current_position
    latitude_i = path_df.loc[shortest_point_idx, "latitude"]
    longitude_i = path_df.loc[shortest_point_idx, "longitude"]
    posi_i = (latitude_i, longitude_i)
    min_d = shortest_distance
    n = shortest_point_idx + 1
    while True:
        try:
            latitude_n = path_df.loc[n, "latitude"]
            longitude_n = path_df.loc[n, "longitude"]
            posi_n = (latitude_n, longitude_n)
            distance = haversine(posi_c, posi_n, unit="km")
            if n == shortest_point_idx + 1:
                path_distance = haversine(posi_i, posi_n, unit="km")
                paths_distance = path_distance
            else:
                path_distance = haversine(posi_n, posi_previous_n, unit="km")
                paths_distance += path_distance

            if distance < (paths_distance + min_d):
                optimal_next_point_idx = n
                return optimal_next_point_idx
            elif n == path_df.index[-1]:
                print("no better optimal_point")
                return shortest_point_idx + 1
            else:
                n = n + 1
                posi_previous_n = posi_n
        except:
            print("no better optimal_point")
            return shortest_point_idx + 1

# %%
# 인덱스 번호를 가지고 항로의 segment 번호를 찾음
# 만약 segment의 마지막 번호라면 seg_no를 하나 더한다.

def find_segment_no(optimal_point_idx, path_df, the_number_of_seg):
    seg_no = optimal_point_idx // (len(path_df) / the_number_of_seg)
    next_no = (optimal_point_idx + 1) // (len(path_df) / the_number_of_seg)
    if seg_no != next_no:
        return int(next_no)
    else:
        return int(seg_no)

# %%
# df 내의 포인트 전체 길이 구하는 함수
def reckon_point_lengths(df_test_2):
    distance = 0
    df_test_2.reset_index(inplace=True, drop=True)
    for idx in df_test_2.index:
        if idx != 0:
            LONGITUDE = df_test_2.loc[idx, "longitude"]
            LATITUDE = df_test_2.loc[idx, "latitude"]
            current_coord = (LATITUDE, LONGITUDE)

            LONGITUDE = df_test_2.loc[idx - 1, "longitude"]
            LATITUDE = df_test_2.loc[idx - 1, "latitude"]
            previous_current_coord = (LATITUDE, LONGITUDE)

            distance += haversine(current_coord, previous_current_coord, unit="km")
    return distance

# %%
def cal_duration(speed, distance):
    hour = int(distance // km_h)
    minute = int(
        (distance / km_h - hour) * 60)
    second = ((distance / km_h - hour) * 60 - minute) * 60
    duration = datetime.timedelta(hours=hour,minutes=minute, seconds=second)
    return duration

# %%
# low_speed_interpolated_df = pd.read_csv(f"실험/upper_china_cosco_fos_high_speed_below_3_knot_{interpolation_number}_concaternated_df.csv")
# low_speed_interpolated_df

# %%
low_speed_interpolated_df = pd.read_csv(f"실험/upper_china_cosco_fos_low_speed_below_3_knot_{interpolation_number}_concaternated_df.csv")
low_speed_interpolated_df
# Out:
#          timestamp   longitude   latitude      speed
# 0     1.668974e+09  117.979120  38.933880  10.280000
# 1     1.668974e+09  117.981084  38.933637  10.388327
# 2     1.668974e+09  117.983048  38.933394  10.496653
# 3     1.668974e+09  117.985012  38.933151  10.604980
# 4     1.668974e+09  117.986977  38.932908  10.713307
# ...            ...         ...        ...        ...
# 9995  1.669262e+09  128.856269  34.909660   8.835972
# 9996  1.669262e+09  128.855447  34.910475   8.826979
# 9997  1.669262e+09  128.854625  34.911290   8.817986
# 9998  1.669262e+09  128.853802  34.912105   8.808993
# 9999  1.669262e+09  128.852980  34.912920   8.800000
#
# [10000 rows x 4 columns]

# %% [markdown]
# ## segment 130

# %%
the_number_of_seg = 130

# %%
seg_length = int(len(low_speed_interpolated_df) / the_number_of_seg)

# %%
# low_speed_df_list = []
# for i in range(the_number_of_seg):
#     idx = seg_length * (i + 1)
#     if i == 0:
#         df = low_speed_interpolated_df.loc[0:idx - 1]
#         df.reset_index(inplace=True)
#     else:
#         df = low_speed_interpolated_df.loc[idx - seg_length:idx - 1]
#         df.reset_index(inplace=True)
#     low_speed_df_list.append(df)

# %%
low_speed_df_list = []
for i in range(the_number_of_seg):
    idx = seg_length * (i + 1)
    if i == 0:
        df = low_speed_interpolated_df.loc[0:idx - 1]
        df.reset_index(inplace=True)
    else:
        df = low_speed_interpolated_df.loc[idx - seg_length:idx - 1]
        df.reset_index(inplace=True)
    low_speed_df_list.append(df)

# %% [markdown]
# # ETA 실험 (interpolation 10000), COSCO FOS 20항차

# %%
cosco_fos_voy_number = "20"

# %%
low_speed_interpolated_df = pd.read_csv(f"실험/upper_china_cosco_fos_low_speed_below_3_knot_{interpolation_number}_concaternated_df.csv")
low_speed_interpolated_df
# Out:
#          timestamp   longitude   latitude      speed
# 0     1.668974e+09  117.979120  38.933880  10.280000
# 1     1.668974e+09  117.981084  38.933637  10.388327
# 2     1.668974e+09  117.983048  38.933394  10.496653
# 3     1.668974e+09  117.985012  38.933151  10.604980
# 4     1.668974e+09  117.986977  38.932908  10.713307
# ...            ...         ...        ...        ...
# 9995  1.669262e+09  128.856269  34.909660   8.835972
# 9996  1.669262e+09  128.855447  34.910475   8.826979
# 9997  1.669262e+09  128.854625  34.911290   8.817986
# 9998  1.669262e+09  128.853802  34.912105   8.808993
# 9999  1.669262e+09  128.852980  34.912920   8.800000
#
# [10000 rows x 4 columns]

# %% [markdown]
# ## segment 130

# %%
# for df in low_speed_df_list:
#     d = df["speed"].mean()
#     print(d)

# %% [markdown]
# ### 저속 (7knot 미만 제거)

# %% [markdown]
# #### 3. 순간 속력 이용 + 알고리즘 x  +  감속 계수 x

# %%
test_df_26 = pd.read_csv(f"voy_path/upper_china/processed/COSCO_FOS_VRKR6_2022_{cosco_fos_voy_number}processed.csv")
test_df_26['timestamp'] = pd.to_datetime(test_df_26['timestamp'])
test_df_26['timestamp'] = pd.to_datetime(test_df_26['timestamp'])
test_df_26['time_voyage_data_received'] = pd.to_datetime(test_df_26['time_voyage_data_received'])
test_df_26.drop('index', axis=1, inplace=True)
test_df_26 = test_df_26.loc[test_df_26[['longitude','latitude','timestamp']].drop_duplicates().index]
test_df_26.reset_index(inplace=True, drop=True)

# %%
for col in test_df_26.index:
    if col == test_df_26.index[-8]:
        break
    # 테스트 데이터
    re_sample = test_df_26.loc[col,:]
    longitude = re_sample["longitude"]
    latitude = re_sample["latitude"]
    current_point = (latitude, longitude)
    
    # 1. 순간 속력 (AIS) 
    current_speed = re_sample["speed"]
    current_position_timestamp = re_sample["timestamp"]
    if current_speed < 7:
        continue
    # 현재 위치에서 가장 짧은 segment 찾기
    shortest_distance = 9999
    for seg_no, seg_df in enumerate(low_speed_df_list):
        for idx in seg_df.index:
            LONGITUDE = seg_df.loc[idx, "longitude"]
            LATITUDE = seg_df.loc[idx, "latitude"]

            ais_point = (LATITUDE, LONGITUDE)
            distance = haversine(current_point, ais_point, unit="km")
            # 가장 짧은 segment 간의 거리, segment 번호, 인덱스 저장
            if distance <= shortest_distance:
                shortest_distance = distance 
                shortest_point_idx = seg_df.loc[idx, "index"]
                shortest_seg_no = seg_no
                
    # 다음 인덱스
#     optimal_point_idx = optimal_next_point(current_point, shortest_point_idx, shortest_distance, low_speed_interpolated_df)
    optimal_point_idx = low_speed_interpolated_df.query(f'index == {shortest_point_idx}').index[0] + 1
    lon_optimal = low_speed_interpolated_df.loc[optimal_point_idx, "longitude"]
    lat_optimal = low_speed_interpolated_df.loc[optimal_point_idx, "latitude"]
    
    optimal_point = (lat_optimal, lon_optimal)
    optimal_distance = haversine(current_point, optimal_point, unit="km")
    km_h = current_speed * 1.852
    init_duration = cal_duration(km_h, optimal_distance)
    
    
    # 가장 가까운 segment 찾기
    
    optimal_seg_no = find_segment_no(optimal_point_idx, low_speed_interpolated_df, the_number_of_seg)
    if optimal_seg_no == the_number_of_seg:
        continue
    initial_seg_df = low_speed_df_list[optimal_seg_no]
    # speed_damping_ratio는 각 segment에 맞게
#     speed_damping_ratio = current_speed / initial_seg_df["speed"].mean()
    speed_damping_ratio = 1
    km_h = current_speed * 1.852 * speed_damping_ratio
    
    
    remaining_initial_seg_df = initial_seg_df.loc[optimal_point_idx:,:]
    remaining_initial_seg_df.reset_index(inplace=True, drop=True)
    accu_distance = 0
    for idx in remaining_initial_seg_df.index:
        if idx != 0:
            LONGITUDE = remaining_initial_seg_df.loc[idx, "longitude"]
            LATITUDE = remaining_initial_seg_df.loc[idx, "latitude"]
            current_coord = (LATITUDE, LONGITUDE)

            LONGITUDE = remaining_initial_seg_df.loc[idx - 1, "longitude"]
            LATITUDE = remaining_initial_seg_df.loc[idx - 1, "latitude"]
            previous_current_coord = (LATITUDE, LONGITUDE)
            
            accu_distance += haversine(current_coord, previous_current_coord, unit="km")
            
    duration_0 = cal_duration(km_h, accu_distance)
    duration_0 = duration_0 + init_duration
    
    
        
    dura_list = []  
    for next_seg_no in range(optimal_seg_no + 1, the_number_of_seg):
        next_seg_df = low_speed_df_list[next_seg_no]
        
        seg_mean_speed = next_seg_df['speed'].mean()
#         speed_damping_ratio = current_speed / seg_mean_speed
        speed_damping_ratio = 1
        damped_mean_speed = seg_mean_speed * speed_damping_ratio
        km_h = damped_mean_speed * 1.852
        distance = reckon_point_lengths(next_seg_df)
        dura_list.append(cal_duration(km_h, distance))
    
    accu_timedelta = datetime.timedelta(seconds=0)
    for i in dura_list:
        accu_timedelta += i
    # 현재 시간 + duration = ETA
    ETA = current_position_timestamp + accu_timedelta
    test_df_26.loc[col,'ETA'] = ETA
    optimal_seg_no = 0

test_df_26['ATA'] = test_df_26.loc[test_df_26.index[-1],"timestamp"]
test_df_26['error'] = abs(test_df_26['ATA'] - test_df_26['ETA'])

experiment_no = f"4.1.1.1_seg_{the_number_of_seg}_{cosco_fos_voy_number}".replace(".","_")
result_df_dict['experiment_no'].append(experiment_no)
result_df_dict['mean_speed'].append(test_df_26.loc[test_df_26.index[:-20]]["error"].mean())
result_df_dict['max_speed'].append(test_df_26.loc[test_df_26.index[:-20]]["error"].max())

globals()[f"exp_result_df_{experiment_no}"] = test_df_26

# %%
print("최대:", test_df_26.loc[test_df_26.index[:-20]]["error"].max())
print("평균:", test_df_26.loc[test_df_26.index[:-20]]["error"].mean())
# Out:
# 최대: 1 days 14:30:24.308333
# 평균: 1 days 01:57:29.464779090

# %%
test_df_26.loc[test_df_26['error'].dropna(axis=0).index].sort_values(by="error")
# Out:
#     vessel_name       mmsi        imo  CAPACITY destination       eta  \
# 168   COSCO FOS  477947700  9484302.0      4253       KRBNP  10041000
# 136   COSCO FOS  477947700  9484302.0      4253       KRBNP  10040800
# 125   COSCO FOS  477947700  9484302.0      4253       KRBNP  10040800
# 135   COSCO FOS  477947700  9484302.0      4253       KRBNP  10040800
# 139   COSCO FOS  477947700  9484302.0      4253       KRBNP  10040800
# ..          ...        ...        ...       ...         ...       ...
# 3     COSCO FOS  477947700  9484302.0      4253       KRBNP  10040800
# 4     COSCO FOS  477947700  9484302.0      4253       KRBNP  10040800
# 0     COSCO FOS  477947700  9484302.0      4253       KRBNP  10040800
# 1     COSCO FOS  477947700  9484302.0      4253       KRBNP  10040800
# 2     COSCO FOS  477947700  9484302.0      4253       KRBNP  10040800
#
#      longitude  latitude  speed  heading                  timestamp  \
# 168   129.0444   34.8247    7.6    151.0 2022-10-04 13:09:01.327977
# 136   126.3324   34.0450   13.0     96.0 2022-10-03 20:07:22.061769
# 125   125.5649   34.5734   12.0    175.0 2022-10-03 14:36:49.989291
# 135   126.2018   34.0441   13.2     88.0 2022-10-03 19:37:19.827269
# 139   126.7036   34.0417   12.6     85.0 2022-10-03 21:37:30.816376
# ..         ...       ...    ...      ...                        ...
# 3     119.0021   38.7842    8.7    108.0 2022-10-01 00:30:50.401793
# 4     119.1093   38.7560    8.2    105.0 2022-10-01 01:00:53.259956
# 0     118.6448   38.7996    9.4    104.0 2022-09-30 23:00:41.873653
# 1     118.8027   38.7914    9.4     93.0 2022-09-30 23:30:45.247203
# 2     118.9141   38.7934    9.2     96.0 2022-10-01 00:01:08.988141
#
#     time_position_data_received time_voyage_data_received  \
# 168  2022-10-04 04:06:04.000000       2022-10-04 03:49:05
# 136  2022-10-03 11:06:33.000000       2022-10-02 12:13:06
# 125  2022-10-03 05:36:22.000000       2022-10-02 12:13:06
# 135  2022-10-03 10:36:53.000000       2022-10-02 12:13:06
# 139         2022-10-03 12:36:33       2022-10-02 12:13:06
# ..                          ...                       ...
# 3           2022-09-30 15:22:00       2022-09-30 03:01:09
# 4           2022-09-30 15:59:42       2022-09-30 03:37:07
# 0           2022-09-30 13:55:21       2022-09-30 01:37:07
# 1           2022-09-30 14:20:30       2022-09-30 02:13:08
# 2           2022-09-30 14:56:28       2022-09-30 02:49:08
#
#             navigation_info  remained_distance  estimated_fuel_consumption  \
# 168  under way using engine          26.086101                   34.224027
# 136  under way using engine         249.997451                  345.139167
# 125  under way using engine         300.500854                  396.147184
# 135  under way using engine         260.991501                  364.095111
# 139  under way using engine         219.618023                  297.273890
# ..                      ...                ...                         ...
# 3    under way using engine         970.062241                 1222.831812
# 4    under way using engine         960.281513                 1227.388613
# 0    under way using engine         999.329431                 1248.920210
# 1    under way using engine         986.319121                 1232.660467
# 2    under way using engine         977.489504                 1223.165075
#
#                            ETA                        ATA  \
# 168 2022-10-04 13:29:11.645913 2022-10-04 19:09:35.172588
# 136 2022-10-04 11:31:13.262739 2022-10-04 19:09:35.172588
# 125 2022-10-04 11:30:02.037455 2022-10-04 19:09:35.172588
# 135 2022-10-04 11:24:01.783810 2022-10-04 19:09:35.172588
# 139 2022-10-04 11:05:33.007884 2022-10-04 19:09:35.172588
# ..                         ...                        ...
# 3   2022-10-03 05:08:52.277907 2022-10-04 19:09:35.172588
# 4   2022-10-03 05:01:24.485612 2022-10-04 19:09:35.172588
# 0   2022-10-03 04:52:00.589308 2022-10-04 19:09:35.172588
# 1   2022-10-03 04:43:36.161183 2022-10-04 19:09:35.172588
# 2   2022-10-03 04:39:10.864255 2022-10-04 19:09:35.172588
#
#                      error
# 168 0 days 05:40:23.526675
# 136 0 days 07:38:21.909849
# 125 0 days 07:39:33.135133
# 135 0 days 07:45:33.388778
# 139 0 days 08:04:02.164704
# ..                     ...
# 3   1 days 14:00:42.894681
# 4   1 days 14:08:10.686976
# 0   1 days 14:17:34.583280
# 1   1 days 14:25:59.011405
# 2   1 days 14:30:24.308333
#
# [112 rows x 19 columns]

# %% [markdown]
# ### 저속 (7knot 미만 포함)

# %% [markdown]
# #### 3. 순간 속력 이용 + 알고리즘 x  +  감속 계수 x

# %%
test_df_26 = pd.read_csv(f"voy_path/upper_china/processed/COSCO_FOS_VRKR6_2022_{cosco_fos_voy_number}processed.csv")
test_df_26['timestamp'] = pd.to_datetime(test_df_26['timestamp'])
test_df_26['timestamp'] = pd.to_datetime(test_df_26['timestamp'])
test_df_26['time_voyage_data_received'] = pd.to_datetime(test_df_26['time_voyage_data_received'])
test_df_26.drop('index', axis=1, inplace=True)
test_df_26 = test_df_26.loc[test_df_26[['longitude','latitude','timestamp']].drop_duplicates().index]
test_df_26.reset_index(inplace=True, drop=True)

# %%
for col in test_df_26.index:
    if col == test_df_26.index[-8]:
        break
    # 테스트 데이터
    re_sample = test_df_26.loc[col,:]
    longitude = re_sample["longitude"]
    latitude = re_sample["latitude"]
    current_point = (latitude, longitude)
    
    # 1. 순간 속력 (AIS) 
    current_speed = re_sample["speed"]
    current_position_timestamp = re_sample["timestamp"]
#     if current_speed < 7:
#         continue
    # 현재 위치에서 가장 짧은 segment 찾기
    shortest_distance = 9999
    for seg_no, seg_df in enumerate(low_speed_df_list):
        for idx in seg_df.index:
            LONGITUDE = seg_df.loc[idx, "longitude"]
            LATITUDE = seg_df.loc[idx, "latitude"]

            ais_point = (LATITUDE, LONGITUDE)
            distance = haversine(current_point, ais_point, unit="km")
            # 가장 짧은 segment 간의 거리, segment 번호, 인덱스 저장
            if distance <= shortest_distance:
                shortest_distance = distance 
                shortest_point_idx = seg_df.loc[idx, "index"]
                shortest_seg_no = seg_no
                
    # 다음 인덱스
#     optimal_point_idx = optimal_next_point(current_point, shortest_point_idx, shortest_distance, low_speed_interpolated_df)
    optimal_point_idx = low_speed_interpolated_df.query(f'index == {shortest_point_idx}').index[0] + 1
    lon_optimal = low_speed_interpolated_df.loc[optimal_point_idx, "longitude"]
    lat_optimal = low_speed_interpolated_df.loc[optimal_point_idx, "latitude"]
    
    optimal_point = (lat_optimal, lon_optimal)
    optimal_distance = haversine(current_point, optimal_point, unit="km")
    km_h = current_speed * 1.852
    init_duration = cal_duration(km_h, optimal_distance)
    
    
    # 가장 가까운 segment 찾기
    
    optimal_seg_no = find_segment_no(optimal_point_idx, low_speed_interpolated_df, the_number_of_seg)
    if optimal_seg_no == the_number_of_seg:
        continue
    initial_seg_df = low_speed_df_list[optimal_seg_no]
    # speed_damping_ratio는 각 segment에 맞게
#     speed_damping_ratio = current_speed / initial_seg_df["speed"].mean()
    speed_damping_ratio = 1
    km_h = current_speed * 1.852 * speed_damping_ratio
    
    
    remaining_initial_seg_df = initial_seg_df.loc[optimal_point_idx:,:]
    remaining_initial_seg_df.reset_index(inplace=True, drop=True)
    accu_distance = 0
    for idx in remaining_initial_seg_df.index:
        if idx != 0:
            LONGITUDE = remaining_initial_seg_df.loc[idx, "longitude"]
            LATITUDE = remaining_initial_seg_df.loc[idx, "latitude"]
            current_coord = (LATITUDE, LONGITUDE)

            LONGITUDE = remaining_initial_seg_df.loc[idx - 1, "longitude"]
            LATITUDE = remaining_initial_seg_df.loc[idx - 1, "latitude"]
            previous_current_coord = (LATITUDE, LONGITUDE)
            
            accu_distance += haversine(current_coord, previous_current_coord, unit="km")
            
    duration_0 = cal_duration(km_h, accu_distance)
    duration_0 = duration_0 + init_duration
    
    
        
    dura_list = []  
    for next_seg_no in range(optimal_seg_no + 1, the_number_of_seg):
        next_seg_df = low_speed_df_list[next_seg_no]
        
        seg_mean_speed = next_seg_df['speed'].mean()
#         speed_damping_ratio = current_speed / seg_mean_speed
        speed_damping_ratio = 1
        damped_mean_speed = seg_mean_speed * speed_damping_ratio
        km_h = damped_mean_speed * 1.852
        distance = reckon_point_lengths(next_seg_df)
        dura_list.append(cal_duration(km_h, distance))
    
    accu_timedelta = datetime.timedelta(seconds=0)
    for i in dura_list:
        accu_timedelta += i
    # 현재 시간 + duration = ETA
    ETA = current_position_timestamp + accu_timedelta
    test_df_26.loc[col,'ETA'] = ETA
    optimal_seg_no = 0

test_df_26['ATA'] = test_df_26.loc[test_df_26.index[-1],"timestamp"]
test_df_26['error'] = abs(test_df_26['ATA'] - test_df_26['ETA'])

experiment_no = f"4.1.2.1_seg_{the_number_of_seg}_{cosco_fos_voy_number}".replace(".","_")
result_df_dict['experiment_no'].append(experiment_no)
result_df_dict['mean_speed'].append(test_df_26.loc[test_df_26.index[:-20]]["error"].mean())
result_df_dict['max_speed'].append(test_df_26.loc[test_df_26.index[:-20]]["error"].max())

globals()[f"exp_result_df_{experiment_no}"] = test_df_26

# %%
print("최대:", test_df_26.loc[test_df_26.index[:-20]]["error"].max())
print("평균:", test_df_26.loc[test_df_26.index[:-20]]["error"].mean())
# Out:
# 최대: 1 days 14:30:24.308333
# 평균: 1 days 00:21:13.972728923

# %%
test_df_26.loc[test_df_26['error'].dropna(axis=0).index].sort_values(by="error")
# Out:
#     vessel_name       mmsi        imo  CAPACITY destination       eta  \
# 168   COSCO FOS  477947700  9484302.0      4253       KRBNP  10041000
# 167   COSCO FOS  477947700  9484302.0      4253       KRBNP  10041000
# 166   COSCO FOS  477947700  9484302.0      4253       KRBNP  10041000
# 165   COSCO FOS  477947700  9484302.0      4253       KRBNP  10041000
# 136   COSCO FOS  477947700  9484302.0      4253       KRBNP  10040800
# ..          ...        ...        ...       ...         ...       ...
# 3     COSCO FOS  477947700  9484302.0      4253       KRBNP  10040800
# 4     COSCO FOS  477947700  9484302.0      4253       KRBNP  10040800
# 0     COSCO FOS  477947700  9484302.0      4253       KRBNP  10040800
# 1     COSCO FOS  477947700  9484302.0      4253       KRBNP  10040800
# 2     COSCO FOS  477947700  9484302.0      4253       KRBNP  10040800
#
#      longitude  latitude  speed  heading                  timestamp  \
# 168   129.0444   34.8247    7.6    151.0 2022-10-04 13:09:01.327977
# 167   129.0293   34.8297    1.7    133.0 2022-10-04 12:38:58.111665
# 166   129.0214   34.8176    1.7    138.0 2022-10-04 12:08:58.953498
# 165   129.0123   34.8078    0.9    195.0 2022-10-04 11:38:52.934934
# 136   126.3324   34.0450   13.0     96.0 2022-10-03 20:07:22.061769
# ..         ...       ...    ...      ...                        ...
# 3     119.0021   38.7842    8.7    108.0 2022-10-01 00:30:50.401793
# 4     119.1093   38.7560    8.2    105.0 2022-10-01 01:00:53.259956
# 0     118.6448   38.7996    9.4    104.0 2022-09-30 23:00:41.873653
# 1     118.8027   38.7914    9.4     93.0 2022-09-30 23:30:45.247203
# 2     118.9141   38.7934    9.2     96.0 2022-10-01 00:01:08.988141
#
#     time_position_data_received time_voyage_data_received  \
# 168  2022-10-04 04:06:04.000000       2022-10-04 03:49:05
# 167  2022-10-04 03:35:32.000000       2022-10-04 03:25:06
# 166         2022-10-04 03:07:59       2022-10-04 03:01:07
# 165         2022-10-04 02:37:48       2022-10-04 02:31:04
# 136  2022-10-03 11:06:33.000000       2022-10-02 12:13:06
# ..                          ...                       ...
# 3           2022-09-30 15:22:00       2022-09-30 03:01:09
# 4           2022-09-30 15:59:42       2022-09-30 03:37:07
# 0           2022-09-30 13:55:21       2022-09-30 01:37:07
# 1           2022-09-30 14:20:30       2022-09-30 02:13:08
# 2           2022-09-30 14:56:28       2022-09-30 02:49:08
#
#             navigation_info  remained_distance  estimated_fuel_consumption  \
# 168  under way using engine          26.086101                   34.224027
# 167  under way using engine          24.662677                  116.081414
# 166  under way using engine          24.998230                  117.660783
# 165  under way using engine          25.161226                  223.166539
# 136  under way using engine         249.997451                  345.139167
# ..                      ...                ...                         ...
# 3    under way using engine         970.062241                 1222.831812
# 4    under way using engine         960.281513                 1227.388613
# 0    under way using engine         999.329431                 1248.920210
# 1    under way using engine         986.319121                 1232.660467
# 2    under way using engine         977.489504                 1223.165075
#
#                            ETA                        ATA  \
# 168 2022-10-04 13:29:11.645913 2022-10-04 19:09:35.172588
# 167 2022-10-04 12:59:08.429601 2022-10-04 19:09:35.172588
# 166 2022-10-04 12:29:09.271434 2022-10-04 19:09:35.172588
# 165 2022-10-04 11:59:03.252870 2022-10-04 19:09:35.172588
# 136 2022-10-04 11:31:13.262739 2022-10-04 19:09:35.172588
# ..                         ...                        ...
# 3   2022-10-03 05:08:52.277907 2022-10-04 19:09:35.172588
# 4   2022-10-03 05:01:24.485612 2022-10-04 19:09:35.172588
# 0   2022-10-03 04:52:00.589308 2022-10-04 19:09:35.172588
# 1   2022-10-03 04:43:36.161183 2022-10-04 19:09:35.172588
# 2   2022-10-03 04:39:10.864255 2022-10-04 19:09:35.172588
#
#                      error
# 168 0 days 05:40:23.526675
# 167 0 days 06:10:26.742987
# 166 0 days 06:40:25.901154
# 165 0 days 07:10:31.919718
# 136 0 days 07:38:21.909849
# ..                     ...
# 3   1 days 14:00:42.894681
# 4   1 days 14:08:10.686976
# 0   1 days 14:17:34.583280
# 1   1 days 14:25:59.011405
# 2   1 days 14:30:24.308333
#
# [169 rows x 19 columns]

# %% [markdown]
# # ETA 실험 (interpolation 10000), COSCO FOS 24항차

# %%
cosco_fos_voy_number = "24"

# %% [markdown]
# ## segment 130

# %% [markdown]
# ### 저속 (7knot 미만 제거)

# %% [markdown]
# #### 3. 순간 속력 이용 + 알고리즘 x  +  감속 계수 x

# %%
test_df_26 = pd.read_csv(f"voy_path/upper_china/processed/COSCO_FOS_VRKR6_2022_{cosco_fos_voy_number}processed.csv")
test_df_26['timestamp'] = pd.to_datetime(test_df_26['timestamp'])
test_df_26['timestamp'] = pd.to_datetime(test_df_26['timestamp'])
test_df_26['time_voyage_data_received'] = pd.to_datetime(test_df_26['time_voyage_data_received'])
test_df_26.drop('index', axis=1, inplace=True)
test_df_26 = test_df_26.loc[test_df_26[['longitude','latitude','timestamp']].drop_duplicates().index]
test_df_26.reset_index(inplace=True, drop=True)

# %%
for col in test_df_26.index:
    if col == test_df_26.index[-8]:
        break
    # 테스트 데이터
    re_sample = test_df_26.loc[col,:]
    longitude = re_sample["longitude"]
    latitude = re_sample["latitude"]
    current_point = (latitude, longitude)
    
    # 1. 순간 속력 (AIS) 
    current_speed = re_sample["speed"]
    current_position_timestamp = re_sample["timestamp"]
    if current_speed < 7:
        continue
    # 현재 위치에서 가장 짧은 segment 찾기
    shortest_distance = 9999
    for seg_no, seg_df in enumerate(low_speed_df_list):
        for idx in seg_df.index:
            LONGITUDE = seg_df.loc[idx, "longitude"]
            LATITUDE = seg_df.loc[idx, "latitude"]

            ais_point = (LATITUDE, LONGITUDE)
            distance = haversine(current_point, ais_point, unit="km")
            # 가장 짧은 segment 간의 거리, segment 번호, 인덱스 저장
            if distance <= shortest_distance:
                shortest_distance = distance 
                shortest_point_idx = seg_df.loc[idx, "index"]
                shortest_seg_no = seg_no
                
    # 다음 인덱스
#     optimal_point_idx = optimal_next_point(current_point, shortest_point_idx, shortest_distance, low_speed_interpolated_df)
    optimal_point_idx = low_speed_interpolated_df.query(f'index == {shortest_point_idx}').index[0] + 1
    lon_optimal = low_speed_interpolated_df.loc[optimal_point_idx, "longitude"]
    lat_optimal = low_speed_interpolated_df.loc[optimal_point_idx, "latitude"]
    
    optimal_point = (lat_optimal, lon_optimal)
    optimal_distance = haversine(current_point, optimal_point, unit="km")
    km_h = current_speed * 1.852
    init_duration = cal_duration(km_h, optimal_distance)
    
    
    # 가장 가까운 segment 찾기
    
    optimal_seg_no = find_segment_no(optimal_point_idx, low_speed_interpolated_df, the_number_of_seg)
    if optimal_seg_no == the_number_of_seg:
        continue
    initial_seg_df = low_speed_df_list[optimal_seg_no]
    # speed_damping_ratio는 각 segment에 맞게
#     speed_damping_ratio = current_speed / initial_seg_df["speed"].mean()
    speed_damping_ratio = 1
    km_h = current_speed * 1.852 * speed_damping_ratio
    
    
    remaining_initial_seg_df = initial_seg_df.loc[optimal_point_idx:,:]
    remaining_initial_seg_df.reset_index(inplace=True, drop=True)
    accu_distance = 0
    for idx in remaining_initial_seg_df.index:
        if idx != 0:
            LONGITUDE = remaining_initial_seg_df.loc[idx, "longitude"]
            LATITUDE = remaining_initial_seg_df.loc[idx, "latitude"]
            current_coord = (LATITUDE, LONGITUDE)

            LONGITUDE = remaining_initial_seg_df.loc[idx - 1, "longitude"]
            LATITUDE = remaining_initial_seg_df.loc[idx - 1, "latitude"]
            previous_current_coord = (LATITUDE, LONGITUDE)
            
            accu_distance += haversine(current_coord, previous_current_coord, unit="km")
            
    duration_0 = cal_duration(km_h, accu_distance)
    duration_0 = duration_0 + init_duration
    
    
        
    dura_list = []  
    for next_seg_no in range(optimal_seg_no + 1, the_number_of_seg):
        next_seg_df = low_speed_df_list[next_seg_no]
        
        seg_mean_speed = next_seg_df['speed'].mean()
#         speed_damping_ratio = current_speed / seg_mean_speed
        speed_damping_ratio = 1
        damped_mean_speed = seg_mean_speed * speed_damping_ratio
        km_h = damped_mean_speed * 1.852
        distance = reckon_point_lengths(next_seg_df)
        dura_list.append(cal_duration(km_h, distance))
    
    accu_timedelta = datetime.timedelta(seconds=0)
    for i in dura_list:
        accu_timedelta += i
    # 현재 시간 + duration = ETA
    ETA = current_position_timestamp + accu_timedelta
    test_df_26.loc[col,'ETA'] = ETA
    optimal_seg_no = 0

test_df_26['ATA'] = test_df_26.loc[test_df_26.index[-1],"timestamp"]
test_df_26['error'] = abs(test_df_26['ATA'] - test_df_26['ETA'])

experiment_no = f"5.1.1.1_seg_{the_number_of_seg}_{cosco_fos_voy_number}".replace(".","_")
result_df_dict['experiment_no'].append(experiment_no)
result_df_dict['mean_speed'].append(test_df_26.loc[test_df_26.index[:-20]]["error"].mean())
result_df_dict['max_speed'].append(test_df_26.loc[test_df_26.index[:-20]]["error"].max())

globals()[f"exp_result_df_{experiment_no}"] = test_df_26

# %%
print("최대:", test_df_26.loc[test_df_26.index[:-20]]["error"].max())
print("평균:", test_df_26.loc[test_df_26.index[:-20]]["error"].mean())
# Out:
# 최대: 0 days 02:16:02.628344
# 평균: 0 days 01:01:48.595966014

# %%
test_df_26.loc[test_df_26['error'].dropna(axis=0).index].sort_values(by="error")
# Out:
#     vessel_name       mmsi        imo  CAPACITY destination       eta  \
# 246   COSCO FOS  477947700  9484302.0      4253       KRBNP  11040700
# 240   COSCO FOS  477947700  9484302.0      4253       KRBNP  11040700
# 251   COSCO FOS  477947700  9484302.0      4253       KRBNP  11040700
# 273   COSCO FOS  477947700  9484302.0      4253       KRBNP  11040800
# 245   COSCO FOS  477947700  9484302.0      4253       KRBNP  11040700
# ..          ...        ...        ...       ...         ...       ...
# 144   COSCO FOS  477947700  9484302.0      4253       KRBNP  11040700
# 141   COSCO FOS  477947700  9484302.0      4253       KRBNP  11040700
# 142   COSCO FOS  477947700  9484302.0      4253       KRBNP  11040700
# 143   COSCO FOS  477947700  9484302.0      4253       KRBNP  11040700
# 22    COSCO FOS  477947700  9484302.0      4253       KRBNP  11040700
#
#      longitude  latitude  speed  heading                  timestamp  \
# 246   128.2969   34.3485   12.4     47.0 2022-11-04 10:52:48.723191
# 240   128.1958   34.3073   12.8     72.0 2022-11-04 10:22:31.346676
# 251   128.4118   34.4064   12.6     62.0 2022-11-04 11:23:05.412089
# 273   128.8036   34.6351    8.0      3.0 2022-11-04 14:09:40.118808
# 245   128.2886   34.3432   12.4     50.0 2022-11-04 10:47:45.786926
# ..         ...       ...    ...      ...                        ...
# 144   125.5721   34.5799   11.6    181.0 2022-11-03 21:55:31.292315
# 141   125.5740   34.6303   11.5    181.0 2022-11-03 21:40:22.633786
# 142   125.5733   34.6142   11.5    181.0 2022-11-03 21:45:26.712762
# 143   125.5726   34.5960   11.7    181.0 2022-11-03 21:50:28.724352
# 22    118.7096   38.7970   14.8    102.0 2022-11-02 12:55:42.639616
#
#     time_position_data_received time_voyage_data_received  \
# 246  2022-11-04 01:49:25.000000       2022-11-04 01:43:07
# 240  2022-11-04 01:22:10.000000       2022-11-04 01:19:06
# 251         2022-11-04 02:21:40       2022-11-04 02:19:06
# 273  2022-11-04 05:08:54.000000       2022-11-04 04:55:07
# 245         2022-11-04 01:47:01       2022-11-04 01:43:07
# ..                          ...                       ...
# 144  2022-11-03 12:55:18.000000       2022-11-02 05:02:27
# 141  2022-11-03 12:39:37.000000       2022-11-02 05:02:27
# 142         2022-11-03 12:44:38       2022-11-02 05:02:27
# 143  2022-11-03 12:50:18.000000       2022-11-02 05:02:27
# 22   2022-11-02 03:55:05.000000       2022-11-02 03:31:09
#
#             navigation_info  remained_distance  estimated_fuel_consumption  \
# 246  under way using engine          83.987916                  112.638144
# 240  under way using engine          93.159743                  127.326007
# 251  under way using engine          72.877156                   98.646164
# 273  under way using engine          37.222897                   47.934953
# 245  under way using engine          84.905888                  113.869258
# ..                      ...                ...                         ...
# 144  under way using engine         299.733567                  389.170279
# 141  under way using engine         298.713155                  386.501330
# 142  under way using engine         299.036478                  386.919673
# 143  under way using engine         299.406223                  390.150220
# 22   under way using engine         994.019358                 1523.794186
#
#                            ETA                        ATA  \
# 246 2022-11-04 16:32:25.192777 2022-11-04 16:30:58.726927
# 240 2022-11-04 16:32:55.065308 2022-11-04 16:30:58.726927
# 251 2022-11-04 16:33:07.339088 2022-11-04 16:30:58.726927
# 273 2022-11-04 16:27:38.944547 2022-11-04 16:30:58.726927
# 245 2022-11-04 16:27:22.256512 2022-11-04 16:30:58.726927
# ..                         ...                        ...
# 144 2022-11-04 18:32:42.263099 2022-11-04 16:30:58.726927
# 141 2022-11-04 18:33:34.681950 2022-11-04 16:30:58.726927
# 142 2022-11-04 18:38:38.760926 2022-11-04 16:30:58.726927
# 143 2022-11-04 18:43:40.772516 2022-11-04 16:30:58.726927
# 22  2022-11-04 18:47:01.355271 2022-11-04 16:30:58.726927
#
#                      error
# 246 0 days 00:01:26.465850
# 240 0 days 00:01:56.338381
# 251 0 days 00:02:08.612161
# 273 0 days 00:03:19.782380
# 245 0 days 00:03:36.470415
# ..                     ...
# 144 0 days 02:01:43.536172
# 141 0 days 02:02:35.955023
# 142 0 days 02:07:40.033999
# 143 0 days 02:12:42.045589
# 22  0 days 02:16:02.628344
#
# [280 rows x 19 columns]

# %% [markdown]
# ### 저속 (7knot 미만 포함)

# %% [markdown]
# #### 3. 순간 속력 이용 + 알고리즘 x  +  감속 계수 x

# %%
test_df_26 = pd.read_csv(f"voy_path/upper_china/processed/COSCO_FOS_VRKR6_2022_{cosco_fos_voy_number}processed.csv")
test_df_26['timestamp'] = pd.to_datetime(test_df_26['timestamp'])
test_df_26['timestamp'] = pd.to_datetime(test_df_26['timestamp'])
test_df_26['time_voyage_data_received'] = pd.to_datetime(test_df_26['time_voyage_data_received'])
test_df_26.drop('index', axis=1, inplace=True)
test_df_26 = test_df_26.loc[test_df_26[['longitude','latitude','timestamp']].drop_duplicates().index]
test_df_26.reset_index(inplace=True, drop=True)

# %%
for col in test_df_26.index:
    if col == test_df_26.index[-8]:
        break
    # 테스트 데이터
    re_sample = test_df_26.loc[col,:]
    longitude = re_sample["longitude"]
    latitude = re_sample["latitude"]
    current_point = (latitude, longitude)
    
    # 1. 순간 속력 (AIS) 
    current_speed = re_sample["speed"]
    current_position_timestamp = re_sample["timestamp"]
#     if current_speed < 7:
#         continue
    # 현재 위치에서 가장 짧은 segment 찾기
    shortest_distance = 9999
    for seg_no, seg_df in enumerate(low_speed_df_list):
        for idx in seg_df.index:
            LONGITUDE = seg_df.loc[idx, "longitude"]
            LATITUDE = seg_df.loc[idx, "latitude"]

            ais_point = (LATITUDE, LONGITUDE)
            distance = haversine(current_point, ais_point, unit="km")
            # 가장 짧은 segment 간의 거리, segment 번호, 인덱스 저장
            if distance <= shortest_distance:
                shortest_distance = distance 
                shortest_point_idx = seg_df.loc[idx, "index"]
                shortest_seg_no = seg_no
                
    # 다음 인덱스
#     optimal_point_idx = optimal_next_point(current_point, shortest_point_idx, shortest_distance, low_speed_interpolated_df)
    optimal_point_idx = low_speed_interpolated_df.query(f'index == {shortest_point_idx}').index[0] + 1
    lon_optimal = low_speed_interpolated_df.loc[optimal_point_idx, "longitude"]
    lat_optimal = low_speed_interpolated_df.loc[optimal_point_idx, "latitude"]
    
    optimal_point = (lat_optimal, lon_optimal)
    optimal_distance = haversine(current_point, optimal_point, unit="km")
    km_h = current_speed * 1.852
    init_duration = cal_duration(km_h, optimal_distance)
    
    
    # 가장 가까운 segment 찾기
    
    optimal_seg_no = find_segment_no(optimal_point_idx, low_speed_interpolated_df, the_number_of_seg)
    if optimal_seg_no == the_number_of_seg:
        continue
    initial_seg_df = low_speed_df_list[optimal_seg_no]
    # speed_damping_ratio는 각 segment에 맞게
#     speed_damping_ratio = current_speed / initial_seg_df["speed"].mean()
    speed_damping_ratio = 1
    km_h = current_speed * 1.852 * speed_damping_ratio
    
    
    remaining_initial_seg_df = initial_seg_df.loc[optimal_point_idx:,:]
    remaining_initial_seg_df.reset_index(inplace=True, drop=True)
    accu_distance = 0
    for idx in remaining_initial_seg_df.index:
        if idx != 0:
            LONGITUDE = remaining_initial_seg_df.loc[idx, "longitude"]
            LATITUDE = remaining_initial_seg_df.loc[idx, "latitude"]
            current_coord = (LATITUDE, LONGITUDE)

            LONGITUDE = remaining_initial_seg_df.loc[idx - 1, "longitude"]
            LATITUDE = remaining_initial_seg_df.loc[idx - 1, "latitude"]
            previous_current_coord = (LATITUDE, LONGITUDE)
            
            accu_distance += haversine(current_coord, previous_current_coord, unit="km")
            
    duration_0 = cal_duration(km_h, accu_distance)
    duration_0 = duration_0 + init_duration
    
    
        
    dura_list = []  
    for next_seg_no in range(optimal_seg_no + 1, the_number_of_seg):
        next_seg_df = low_speed_df_list[next_seg_no]
        
        seg_mean_speed = next_seg_df['speed'].mean()
#         speed_damping_ratio = current_speed / seg_mean_speed
        speed_damping_ratio = 1
        damped_mean_speed = seg_mean_speed * speed_damping_ratio
        km_h = damped_mean_speed * 1.852
        distance = reckon_point_lengths(next_seg_df)
        dura_list.append(cal_duration(km_h, distance))
    
    accu_timedelta = datetime.timedelta(seconds=0)
    for i in dura_list:
        accu_timedelta += i
    # 현재 시간 + duration = ETA
    ETA = current_position_timestamp + accu_timedelta
    test_df_26.loc[col,'ETA'] = ETA
    optimal_seg_no = 0

test_df_26['ATA'] = test_df_26.loc[test_df_26.index[-1],"timestamp"]
test_df_26['error'] = abs(test_df_26['ATA'] - test_df_26['ETA'])

experiment_no = f"5.1.2.1_seg_{the_number_of_seg}_{cosco_fos_voy_number}".replace(".","_")
result_df_dict['experiment_no'].append(experiment_no)
result_df_dict['mean_speed'].append(test_df_26.loc[test_df_26.index[:-20]]["error"].mean())
result_df_dict['max_speed'].append(test_df_26.loc[test_df_26.index[:-20]]["error"].max())

globals()[f"exp_result_df_{experiment_no}"] = test_df_26

# %%
print("최대:", test_df_26.loc[test_df_26.index[:-20]]["error"].max())
print("평균:", test_df_26.loc[test_df_26.index[:-20]]["error"].mean())
# Out:
# 최대: 0 days 02:16:02.628344
# 평균: 0 days 01:01:01.838284289

# %%
test_df_26.loc[test_df_26['error'].dropna(axis=0).index].sort_values(by="error")
# Out:
#     vessel_name       mmsi        imo  CAPACITY destination       eta  \
# 246   COSCO FOS  477947700  9484302.0      4253       KRBNP  11040700
# 240   COSCO FOS  477947700  9484302.0      4253       KRBNP  11040700
# 251   COSCO FOS  477947700  9484302.0      4253       KRBNP  11040700
# 273   COSCO FOS  477947700  9484302.0      4253       KRBNP  11040800
# 245   COSCO FOS  477947700  9484302.0      4253       KRBNP  11040700
# ..          ...        ...        ...       ...         ...       ...
# 144   COSCO FOS  477947700  9484302.0      4253       KRBNP  11040700
# 141   COSCO FOS  477947700  9484302.0      4253       KRBNP  11040700
# 142   COSCO FOS  477947700  9484302.0      4253       KRBNP  11040700
# 143   COSCO FOS  477947700  9484302.0      4253       KRBNP  11040700
# 22    COSCO FOS  477947700  9484302.0      4253       KRBNP  11040700
#
#      longitude  latitude  speed  heading                  timestamp  \
# 246   128.2969   34.3485   12.4     47.0 2022-11-04 10:52:48.723191
# 240   128.1958   34.3073   12.8     72.0 2022-11-04 10:22:31.346676
# 251   128.4118   34.4064   12.6     62.0 2022-11-04 11:23:05.412089
# 273   128.8036   34.6351    8.0      3.0 2022-11-04 14:09:40.118808
# 245   128.2886   34.3432   12.4     50.0 2022-11-04 10:47:45.786926
# ..         ...       ...    ...      ...                        ...
# 144   125.5721   34.5799   11.6    181.0 2022-11-03 21:55:31.292315
# 141   125.5740   34.6303   11.5    181.0 2022-11-03 21:40:22.633786
# 142   125.5733   34.6142   11.5    181.0 2022-11-03 21:45:26.712762
# 143   125.5726   34.5960   11.7    181.0 2022-11-03 21:50:28.724352
# 22    118.7096   38.7970   14.8    102.0 2022-11-02 12:55:42.639616
#
#     time_position_data_received time_voyage_data_received  \
# 246  2022-11-04 01:49:25.000000       2022-11-04 01:43:07
# 240  2022-11-04 01:22:10.000000       2022-11-04 01:19:06
# 251         2022-11-04 02:21:40       2022-11-04 02:19:06
# 273  2022-11-04 05:08:54.000000       2022-11-04 04:55:07
# 245         2022-11-04 01:47:01       2022-11-04 01:43:07
# ..                          ...                       ...
# 144  2022-11-03 12:55:18.000000       2022-11-02 05:02:27
# 141  2022-11-03 12:39:37.000000       2022-11-02 05:02:27
# 142         2022-11-03 12:44:38       2022-11-02 05:02:27
# 143  2022-11-03 12:50:18.000000       2022-11-02 05:02:27
# 22   2022-11-02 03:55:05.000000       2022-11-02 03:31:09
#
#             navigation_info  remained_distance  estimated_fuel_consumption  \
# 246  under way using engine          83.987916                  112.638144
# 240  under way using engine          93.159743                  127.326007
# 251  under way using engine          72.877156                   98.646164
# 273  under way using engine          37.222897                   47.934953
# 245  under way using engine          84.905888                  113.869258
# ..                      ...                ...                         ...
# 144  under way using engine         299.733567                  389.170279
# 141  under way using engine         298.713155                  386.501330
# 142  under way using engine         299.036478                  386.919673
# 143  under way using engine         299.406223                  390.150220
# 22   under way using engine         994.019358                 1523.794186
#
#                            ETA                        ATA  \
# 246 2022-11-04 16:32:25.192777 2022-11-04 16:30:58.726927
# 240 2022-11-04 16:32:55.065308 2022-11-04 16:30:58.726927
# 251 2022-11-04 16:33:07.339088 2022-11-04 16:30:58.726927
# 273 2022-11-04 16:27:38.944547 2022-11-04 16:30:58.726927
# 245 2022-11-04 16:27:22.256512 2022-11-04 16:30:58.726927
# ..                         ...                        ...
# 144 2022-11-04 18:32:42.263099 2022-11-04 16:30:58.726927
# 141 2022-11-04 18:33:34.681950 2022-11-04 16:30:58.726927
# 142 2022-11-04 18:38:38.760926 2022-11-04 16:30:58.726927
# 143 2022-11-04 18:43:40.772516 2022-11-04 16:30:58.726927
# 22  2022-11-04 18:47:01.355271 2022-11-04 16:30:58.726927
#
#                      error
# 246 0 days 00:01:26.465850
# 240 0 days 00:01:56.338381
# 251 0 days 00:02:08.612161
# 273 0 days 00:03:19.782380
# 245 0 days 00:03:36.470415
# ..                     ...
# 144 0 days 02:01:43.536172
# 141 0 days 02:02:35.955023
# 142 0 days 02:07:40.033999
# 143 0 days 02:12:42.045589
# 22  0 days 02:16:02.628344
#
# [285 rows x 19 columns]

# %% [markdown]
# # ETA 실험 (interpolation 10000), COSCO FOS 28항차

# %%
cosco_fos_voy_number = "28"

# %% [markdown]
# ## segment 130

# %% [markdown]
# ### 저속 (7knot 미만 제거)

# %% [markdown]
# #### 3. 순간 속력 이용 + 알고리즘 x  +  감속 계수 x

# %%
test_df_26 = pd.read_csv(f"voy_path/upper_china/processed/COSCO_FOS_VRKR6_2022_{cosco_fos_voy_number}processed.csv")
test_df_26['timestamp'] = pd.to_datetime(test_df_26['timestamp'])
test_df_26['timestamp'] = pd.to_datetime(test_df_26['timestamp'])
test_df_26['time_voyage_data_received'] = pd.to_datetime(test_df_26['time_voyage_data_received'])
test_df_26.drop('index', axis=1, inplace=True)
test_df_26 = test_df_26.loc[test_df_26[['longitude','latitude','timestamp']].drop_duplicates().index]
test_df_26.reset_index(inplace=True, drop=True)

# %%
for col in test_df_26.index:
    if col == test_df_26.index[-8]:
        break
    # 테스트 데이터
    re_sample = test_df_26.loc[col,:]
    longitude = re_sample["longitude"]
    latitude = re_sample["latitude"]
    current_point = (latitude, longitude)
    
    # 1. 순간 속력 (AIS) 
    current_speed = re_sample["speed"]
    current_position_timestamp = re_sample["timestamp"]
    if current_speed < 7:
        continue
    # 현재 위치에서 가장 짧은 segment 찾기
    shortest_distance = 9999
    for seg_no, seg_df in enumerate(low_speed_df_list):
        for idx in seg_df.index:
            LONGITUDE = seg_df.loc[idx, "longitude"]
            LATITUDE = seg_df.loc[idx, "latitude"]

            ais_point = (LATITUDE, LONGITUDE)
            distance = haversine(current_point, ais_point, unit="km")
            # 가장 짧은 segment 간의 거리, segment 번호, 인덱스 저장
            if distance <= shortest_distance:
                shortest_distance = distance 
                shortest_point_idx = seg_df.loc[idx, "index"]
                shortest_seg_no = seg_no
                
    # 다음 인덱스
#     optimal_point_idx = optimal_next_point(current_point, shortest_point_idx, shortest_distance, low_speed_interpolated_df)
    optimal_point_idx = low_speed_interpolated_df.query(f'index == {shortest_point_idx}').index[0] + 1
    lon_optimal = low_speed_interpolated_df.loc[optimal_point_idx, "longitude"]
    lat_optimal = low_speed_interpolated_df.loc[optimal_point_idx, "latitude"]
    
    optimal_point = (lat_optimal, lon_optimal)
    optimal_distance = haversine(current_point, optimal_point, unit="km")
    km_h = current_speed * 1.852
    init_duration = cal_duration(km_h, optimal_distance)
    
    
    # 가장 가까운 segment 찾기
    
    optimal_seg_no = find_segment_no(optimal_point_idx, low_speed_interpolated_df, the_number_of_seg)
    if optimal_seg_no == the_number_of_seg:
        continue
    initial_seg_df = low_speed_df_list[optimal_seg_no]
    # speed_damping_ratio는 각 segment에 맞게
#     speed_damping_ratio = current_speed / initial_seg_df["speed"].mean()
    speed_damping_ratio = 1
    km_h = current_speed * 1.852 * speed_damping_ratio
    
    
    remaining_initial_seg_df = initial_seg_df.loc[optimal_point_idx:,:]
    remaining_initial_seg_df.reset_index(inplace=True, drop=True)
    accu_distance = 0
    for idx in remaining_initial_seg_df.index:
        if idx != 0:
            LONGITUDE = remaining_initial_seg_df.loc[idx, "longitude"]
            LATITUDE = remaining_initial_seg_df.loc[idx, "latitude"]
            current_coord = (LATITUDE, LONGITUDE)

            LONGITUDE = remaining_initial_seg_df.loc[idx - 1, "longitude"]
            LATITUDE = remaining_initial_seg_df.loc[idx - 1, "latitude"]
            previous_current_coord = (LATITUDE, LONGITUDE)
            
            accu_distance += haversine(current_coord, previous_current_coord, unit="km")
            
    duration_0 = cal_duration(km_h, accu_distance)
    duration_0 = duration_0 + init_duration
    
    
        
    dura_list = []  
    for next_seg_no in range(optimal_seg_no + 1, the_number_of_seg):
        next_seg_df = low_speed_df_list[next_seg_no]
        
        seg_mean_speed = next_seg_df['speed'].mean()
#         speed_damping_ratio = current_speed / seg_mean_speed
        speed_damping_ratio = 1
        damped_mean_speed = seg_mean_speed * speed_damping_ratio
        km_h = damped_mean_speed * 1.852
        distance = reckon_point_lengths(next_seg_df)
        dura_list.append(cal_duration(km_h, distance))
    
    accu_timedelta = datetime.timedelta(seconds=0)
    for i in dura_list:
        accu_timedelta += i
    # 현재 시간 + duration = ETA
    ETA = current_position_timestamp + accu_timedelta
    test_df_26.loc[col,'ETA'] = ETA
    optimal_seg_no = 0

test_df_26['ATA'] = test_df_26.loc[test_df_26.index[-1],"timestamp"]
test_df_26['error'] = abs(test_df_26['ATA'] - test_df_26['ETA'])

experiment_no = f"6.1.1.1_seg_{the_number_of_seg}_{cosco_fos_voy_number}".replace(".","_")
result_df_dict['experiment_no'].append(experiment_no)
result_df_dict['mean_speed'].append(test_df_26.loc[test_df_26.index[:-20]]["error"].mean())
result_df_dict['max_speed'].append(test_df_26.loc[test_df_26.index[:-20]]["error"].max())

globals()[f"exp_result_df_{experiment_no}"] = test_df_26

# %%
print("최대:", test_df_26.loc[test_df_26.index[:-20]]["error"].max())
print("평균:", test_df_26.loc[test_df_26.index[:-20]]["error"].mean())
# Out:
# 최대: 2 days 00:28:15.525331
# 평균: 0 days 23:31:12.763457590

# %%
test_df_26.loc[test_df_26['error'].dropna(axis=0).index].sort_values(by="error")
# Out:
#     vessel_name       mmsi        imo  CAPACITY destination       eta  \
# 405   COSCO FOS  477947700  9484302.0      4253       KRBNP  12080500
# 343   COSCO FOS  477947700  9484302.0      4253       KRBNP  12080500
# 342   COSCO FOS  477947700  9484302.0      4253       KRBNP  12080500
# 347   COSCO FOS  477947700  9484302.0      4253       KRBNP  12080500
# 363   COSCO FOS  477947700  9484302.0      4253       KRBNP  12080500
# ..          ...        ...        ...       ...         ...       ...
# 8     COSCO FOS  477947700  9484302.0      4253       KRBNP  12070300
# 4     COSCO FOS  477947700  9484302.0      4253       KRBNP  12070300
# 3     COSCO FOS  477947700  9484302.0      4253       KRBNP  12070300
# 2     COSCO FOS  477947700  9484302.0      4253       KRBNP  12060100
# 1     COSCO FOS  477947700  9484302.0      4253       KRBNP  12060100
#
#      longitude  latitude  speed  heading                  timestamp  \
# 405   128.9000   34.6430   12.0    355.0 2022-12-09 03:51:42.587630
# 343   128.3604   34.2514    8.8     65.0 2022-12-08 19:00:22.879793
# 342   128.3494   34.2468    8.7     65.0 2022-12-08 18:55:21.836338
# 347   128.4247   34.2811    8.8     55.0 2022-12-08 19:25:33.769193
# 363   128.7495   34.5145    7.8     55.0 2022-12-08 22:00:50.611102
# ..         ...       ...    ...      ...                        ...
# 8     118.1335   38.8934   12.6    135.0 2022-12-04 21:44:27.528578
# 4     117.9479   38.9469   14.7    101.0 2022-12-04 21:04:12.080523
# 3     117.9228   38.9507   13.8    103.0 2022-12-04 20:59:12.162023
# 2     117.8557   38.9607   12.7    103.0 2022-12-04 20:44:05.043774
# 1     117.7925   38.9707    9.3    102.0 2022-12-04 20:29:00.647446
#
#     time_position_data_received time_voyage_data_received  \
# 405  2022-12-08 18:50:00.000000       2022-12-08 06:49:06
# 343  2022-12-08 09:59:17.000000       2022-12-08 09:43:07
# 342  2022-12-08 09:55:06.000000       2022-12-08 09:43:07
# 347  2022-12-08 10:23:49.000000       2022-12-08 10:07:07
# 363  2022-12-08 12:55:30.000000       2022-12-08 12:55:05
# ..                          ...                       ...
# 8    2022-12-04 12:42:44.000000       2022-12-04 12:31:09
# 4    2022-12-04 12:02:09.000000       2022-12-04 12:01:10
# 3    2022-12-04 11:57:04.000000       2022-12-04 11:54:23
# 2    2022-12-04 11:42:03.000000       2022-12-04 11:37:08
# 1    2022-12-04 11:27:04.000000       2022-12-04 11:13:09
#
#             navigation_info  remained_distance  estimated_fuel_consumption  \
# 405  under way using engine          37.053470                    2.035300
# 343  under way using engine          90.235962                    4.730201
# 342  under way using engine          91.160206                    4.788078
# 347  under way using engine          84.650506                    4.437409
# 363  under way using engine          51.006904                    2.760787
# ..                      ...                ...                         ...
# 8    under way using engine        1044.323784                   58.899650
# 4    under way using engine        1061.444496                   67.368341
# 3    under way using engine        1063.620736                   63.917685
# 2    under way using engine        1069.432836                   60.605109
# 1    under way using engine        1074.931265                   56.003970
#
#                            ETA                        ATA  \
# 405 2022-12-09 05:16:28.323096 2022-12-09 05:11:54.876446
# 343 2022-12-09 01:10:46.598425 2022-12-09 05:11:54.876446
# 342 2022-12-09 01:05:45.554970 2022-12-09 05:11:54.876446
# 347 2022-12-09 01:05:10.238779 2022-12-09 05:11:54.876446
# 363 2022-12-09 01:01:18.296547 2022-12-09 05:11:54.876446
# ..                         ...                        ...
# 8   2022-12-07 05:22:58.433928 2022-12-09 05:11:54.876446
# 4   2022-12-07 05:18:50.784192 2022-12-09 05:11:54.876446
# 3   2022-12-07 05:13:50.865692 2022-12-09 05:11:54.876446
# 2   2022-12-07 04:58:43.747443 2022-12-09 05:11:54.876446
# 1   2022-12-07 04:43:39.351115 2022-12-09 05:11:54.876446
#
#                      error
# 405 0 days 00:04:33.446650
# 343 0 days 04:01:08.278021
# 342 0 days 04:06:09.321476
# 347 0 days 04:06:44.637667
# 363 0 days 04:10:36.579899
# ..                     ...
# 8   1 days 23:48:56.442518
# 4   1 days 23:53:04.092254
# 3   1 days 23:58:04.010754
# 2   2 days 00:13:11.129003
# 1   2 days 00:28:15.525331
#
# [262 rows x 19 columns]

# %% [markdown]
# ### 저속 (7knot 미만 포함)

# %% [markdown]
# #### 3. 순간 속력 이용 + 알고리즘 x  +  감속 계수 x

# %%
test_df_26 = pd.read_csv(f"voy_path/upper_china/processed/COSCO_FOS_VRKR6_2022_{cosco_fos_voy_number}processed.csv")
test_df_26['timestamp'] = pd.to_datetime(test_df_26['timestamp'])
test_df_26['timestamp'] = pd.to_datetime(test_df_26['timestamp'])
test_df_26['time_voyage_data_received'] = pd.to_datetime(test_df_26['time_voyage_data_received'])
test_df_26.drop('index', axis=1, inplace=True)
test_df_26 = test_df_26.loc[test_df_26[['longitude','latitude','timestamp']].drop_duplicates().index]
test_df_26.reset_index(inplace=True, drop=True)

# %%
for col in test_df_26.index:
    if col == test_df_26.index[-8]:
        break
    # 테스트 데이터
    re_sample = test_df_26.loc[col,:]
    longitude = re_sample["longitude"]
    latitude = re_sample["latitude"]
    current_point = (latitude, longitude)
    
    # 1. 순간 속력 (AIS) 
    current_speed = re_sample["speed"]
    current_position_timestamp = re_sample["timestamp"]
#     if current_speed < 7:
#         continue
    # 현재 위치에서 가장 짧은 segment 찾기
    shortest_distance = 9999
    for seg_no, seg_df in enumerate(low_speed_df_list):
        for idx in seg_df.index:
            LONGITUDE = seg_df.loc[idx, "longitude"]
            LATITUDE = seg_df.loc[idx, "latitude"]

            ais_point = (LATITUDE, LONGITUDE)
            distance = haversine(current_point, ais_point, unit="km")
            # 가장 짧은 segment 간의 거리, segment 번호, 인덱스 저장
            if distance <= shortest_distance:
                shortest_distance = distance 
                shortest_point_idx = seg_df.loc[idx, "index"]
                shortest_seg_no = seg_no
                
    # 다음 인덱스
#     optimal_point_idx = optimal_next_point(current_point, shortest_point_idx, shortest_distance, low_speed_interpolated_df)
    optimal_point_idx = low_speed_interpolated_df.query(f'index == {shortest_point_idx}').index[0] + 1
    lon_optimal = low_speed_interpolated_df.loc[optimal_point_idx, "longitude"]
    lat_optimal = low_speed_interpolated_df.loc[optimal_point_idx, "latitude"]
    
    optimal_point = (lat_optimal, lon_optimal)
    optimal_distance = haversine(current_point, optimal_point, unit="km")
    km_h = current_speed * 1.852
    init_duration = cal_duration(km_h, optimal_distance)
    
    
    # 가장 가까운 segment 찾기
    
    optimal_seg_no = find_segment_no(optimal_point_idx, low_speed_interpolated_df, the_number_of_seg)
    if optimal_seg_no == the_number_of_seg:
        continue
    initial_seg_df = low_speed_df_list[optimal_seg_no]
    # speed_damping_ratio는 각 segment에 맞게
#     speed_damping_ratio = current_speed / initial_seg_df["speed"].mean()
    speed_damping_ratio = 1
    km_h = current_speed * 1.852 * speed_damping_ratio
    
    
    remaining_initial_seg_df = initial_seg_df.loc[optimal_point_idx:,:]
    remaining_initial_seg_df.reset_index(inplace=True, drop=True)
    accu_distance = 0
    for idx in remaining_initial_seg_df.index:
        if idx != 0:
            LONGITUDE = remaining_initial_seg_df.loc[idx, "longitude"]
            LATITUDE = remaining_initial_seg_df.loc[idx, "latitude"]
            current_coord = (LATITUDE, LONGITUDE)

            LONGITUDE = remaining_initial_seg_df.loc[idx - 1, "longitude"]
            LATITUDE = remaining_initial_seg_df.loc[idx - 1, "latitude"]
            previous_current_coord = (LATITUDE, LONGITUDE)
            
            accu_distance += haversine(current_coord, previous_current_coord, unit="km")
            
    duration_0 = cal_duration(km_h, accu_distance)
    duration_0 = duration_0 + init_duration
    
    
        
    dura_list = []  
    for next_seg_no in range(optimal_seg_no + 1, the_number_of_seg):
        next_seg_df = low_speed_df_list[next_seg_no]
        
        seg_mean_speed = next_seg_df['speed'].mean()
#         speed_damping_ratio = current_speed / seg_mean_speed
        speed_damping_ratio = 1
        damped_mean_speed = seg_mean_speed * speed_damping_ratio
        km_h = damped_mean_speed * 1.852
        distance = reckon_point_lengths(next_seg_df)
        dura_list.append(cal_duration(km_h, distance))
    
    accu_timedelta = datetime.timedelta(seconds=0)
    for i in dura_list:
        accu_timedelta += i
    # 현재 시간 + duration = ETA
    ETA = current_position_timestamp + accu_timedelta
    test_df_26.loc[col,'ETA'] = ETA
    optimal_seg_no = 0

test_df_26['ATA'] = test_df_26.loc[test_df_26.index[-1],"timestamp"]
test_df_26['error'] = abs(test_df_26['ATA'] - test_df_26['ETA'])

experiment_no = f"6.1.2.1_seg_{the_number_of_seg}_{cosco_fos_voy_number}".replace(".","_")
result_df_dict['experiment_no'].append(experiment_no)
result_df_dict['mean_speed'].append(test_df_26.loc[test_df_26.index[:-20]]["error"].mean())
result_df_dict['max_speed'].append(test_df_26.loc[test_df_26.index[:-20]]["error"].max())

globals()[f"exp_result_df_{experiment_no}"] = test_df_26

# %%
print("최대:", test_df_26.loc[test_df_26.index[:-20]]["error"].max())
print("평균:", test_df_26.loc[test_df_26.index[:-20]]["error"].mean())
# Out:
# 최대: 2 days 00:33:18.515470
# 평균: 0 days 21:05:55.070685982

# %%
test_df_26.loc[test_df_26['error'].dropna(axis=0).index].sort_values(by="error")
# Out:
#     vessel_name       mmsi        imo  CAPACITY destination       eta  \
# 404   COSCO FOS  477947700  9484302.0      4253       KRBNP  12080500
# 405   COSCO FOS  477947700  9484302.0      4253       KRBNP  12080500
# 403   COSCO FOS  477947700  9484302.0      4253       KRBNP  12080500
# 402   COSCO FOS  477947700  9484302.0      4253       KRBNP  12080500
# 401   COSCO FOS  477947700  9484302.0      4253       KRBNP  12080500
# ..          ...        ...        ...       ...         ...       ...
# 4     COSCO FOS  477947700  9484302.0      4253       KRBNP  12070300
# 3     COSCO FOS  477947700  9484302.0      4253       KRBNP  12070300
# 2     COSCO FOS  477947700  9484302.0      4253       KRBNP  12060100
# 1     COSCO FOS  477947700  9484302.0      4253       KRBNP  12060100
# 0     COSCO FOS  477947700  9484302.0      4253       KRBNP  12060100
#
#      longitude  latitude  speed  heading                  timestamp  \
# 404   128.9041   34.6018    4.4    357.0 2022-12-09 03:36:40.354032
# 405   128.9000   34.6430   12.0    355.0 2022-12-09 03:51:42.587630
# 403   128.9075   34.6025    0.6    289.0 2022-12-09 03:21:37.839766
# 402   128.9071   34.6032    0.6    293.0 2022-12-09 03:16:37.471178
# 401   128.9061   34.6050    0.7    295.0 2022-12-09 03:06:35.565585
# ..         ...       ...    ...      ...                        ...
# 4     117.9479   38.9469   14.7    101.0 2022-12-04 21:04:12.080523
# 3     117.9228   38.9507   13.8    103.0 2022-12-04 20:59:12.162023
# 2     117.8557   38.9607   12.7    103.0 2022-12-04 20:44:05.043774
# 1     117.7925   38.9707    9.3    102.0 2022-12-04 20:29:00.647446
# 0     117.7766   38.9734    6.7    104.0 2022-12-04 20:23:57.657307
#
#     time_position_data_received time_voyage_data_received  \
# 404  2022-12-08 18:34:53.000000       2022-12-08 06:25:06
# 405  2022-12-08 18:50:00.000000       2022-12-08 06:49:06
# 403  2022-12-08 18:19:50.000000       2022-12-08 06:13:06
# 402  2022-12-08 18:15:25.000000       2022-12-08 06:13:06
# 401  2022-12-08 18:04:40.000000       2022-12-08 05:49:07
# ..                          ...                       ...
# 4    2022-12-04 12:02:09.000000       2022-12-04 12:01:10
# 3    2022-12-04 11:57:04.000000       2022-12-04 11:54:23
# 2    2022-12-04 11:42:03.000000       2022-12-04 11:37:08
# 1    2022-12-04 11:27:04.000000       2022-12-04 11:13:09
# 0    2022-12-04 11:21:11.000000       2022-12-04 11:13:09
#
#             navigation_info  remained_distance  estimated_fuel_consumption  \
# 404  under way using engine          41.621754                    3.297304
# 405  under way using engine          37.053470                    2.035300
# 403  under way using engine          41.604162                   23.056184
# 402  under way using engine          41.520732                   23.009949
# 401  under way using engine          41.306745                   19.622584
# ..                      ...                ...                         ...
# 4    under way using engine        1061.444496                   67.368341
# 3    under way using engine        1063.620736                   63.917685
# 2    under way using engine        1069.432836                   60.605109
# 1    under way using engine        1074.931265                   56.003970
# 0    under way using engine        1076.322026                   62.543332
#
#                            ETA                        ATA  \
# 404 2022-12-09 05:14:19.000929 2022-12-09 05:11:54.876446
# 405 2022-12-09 05:16:28.323096 2022-12-09 05:11:54.876446
# 403 2022-12-09 04:59:16.486663 2022-12-09 05:11:54.876446
# 402 2022-12-09 04:54:16.118075 2022-12-09 05:11:54.876446
# 401 2022-12-09 04:44:14.212482 2022-12-09 05:11:54.876446
# ..                         ...                        ...
# 4   2022-12-07 05:18:50.784192 2022-12-09 05:11:54.876446
# 3   2022-12-07 05:13:50.865692 2022-12-09 05:11:54.876446
# 2   2022-12-07 04:58:43.747443 2022-12-09 05:11:54.876446
# 1   2022-12-07 04:43:39.351115 2022-12-09 05:11:54.876446
# 0   2022-12-07 04:38:36.360976 2022-12-09 05:11:54.876446
#
#                      error
# 404 0 days 00:02:24.124483
# 405 0 days 00:04:33.446650
# 403 0 days 00:12:38.389783
# 402 0 days 00:17:38.758371
# 401 0 days 00:27:40.663964
# ..                     ...
# 4   1 days 23:53:04.092254
# 3   1 days 23:58:04.010754
# 2   2 days 00:13:11.129003
# 1   2 days 00:28:15.525331
# 0   2 days 00:33:18.515470
#
# [406 rows x 19 columns]

# %% [markdown]
# # ETA 실험 (interpolation 10000), COSCO FOS 29항차

# %%
cosco_fos_voy_number = "29"

# %% [markdown]
# ## segment 130

# %% [markdown]
# ### 저속 (7knot 미만 제거)

# %% [markdown]
# #### 3. 순간 속력 이용 + 알고리즘 x  +  감속 계수 x

# %%
test_df_26 = pd.read_csv(f"voy_path/upper_china/processed/COSCO_FOS_VRKR6_2022_{cosco_fos_voy_number}processed.csv")
test_df_26['timestamp'] = pd.to_datetime(test_df_26['timestamp'])
test_df_26['timestamp'] = pd.to_datetime(test_df_26['timestamp'])
test_df_26['time_voyage_data_received'] = pd.to_datetime(test_df_26['time_voyage_data_received'])
test_df_26.drop('index', axis=1, inplace=True)
test_df_26 = test_df_26.loc[test_df_26[['longitude','latitude','timestamp']].drop_duplicates().index]
test_df_26.reset_index(inplace=True, drop=True)

# %%
for col in test_df_26.index:
    if col == test_df_26.index[-8]:
        break
    # 테스트 데이터
    re_sample = test_df_26.loc[col,:]
    longitude = re_sample["longitude"]
    latitude = re_sample["latitude"]
    current_point = (latitude, longitude)
    
    # 1. 순간 속력 (AIS) 
    current_speed = re_sample["speed"]
    current_position_timestamp = re_sample["timestamp"]
    if current_speed < 7:
        continue
    # 현재 위치에서 가장 짧은 segment 찾기
    shortest_distance = 9999
    for seg_no, seg_df in enumerate(low_speed_df_list):
        for idx in seg_df.index:
            LONGITUDE = seg_df.loc[idx, "longitude"]
            LATITUDE = seg_df.loc[idx, "latitude"]

            ais_point = (LATITUDE, LONGITUDE)
            distance = haversine(current_point, ais_point, unit="km")
            # 가장 짧은 segment 간의 거리, segment 번호, 인덱스 저장
            if distance <= shortest_distance:
                shortest_distance = distance 
                shortest_point_idx = seg_df.loc[idx, "index"]
                shortest_seg_no = seg_no
                
    # 다음 인덱스
#     optimal_point_idx = optimal_next_point(current_point, shortest_point_idx, shortest_distance, low_speed_interpolated_df)
    optimal_point_idx = low_speed_interpolated_df.query(f'index == {shortest_point_idx}').index[0] + 1
    lon_optimal = low_speed_interpolated_df.loc[optimal_point_idx, "longitude"]
    lat_optimal = low_speed_interpolated_df.loc[optimal_point_idx, "latitude"]
    
    optimal_point = (lat_optimal, lon_optimal)
    optimal_distance = haversine(current_point, optimal_point, unit="km")
    km_h = current_speed * 1.852
    init_duration = cal_duration(km_h, optimal_distance)
    
    
    # 가장 가까운 segment 찾기
    
    optimal_seg_no = find_segment_no(optimal_point_idx, low_speed_interpolated_df, the_number_of_seg)
    if optimal_seg_no == the_number_of_seg:
        continue
    initial_seg_df = low_speed_df_list[optimal_seg_no]
    # speed_damping_ratio는 각 segment에 맞게
#     speed_damping_ratio = current_speed / initial_seg_df["speed"].mean()
    speed_damping_ratio = 1
    km_h = current_speed * 1.852 * speed_damping_ratio
    
    
    remaining_initial_seg_df = initial_seg_df.loc[optimal_point_idx:,:]
    remaining_initial_seg_df.reset_index(inplace=True, drop=True)
    accu_distance = 0
    for idx in remaining_initial_seg_df.index:
        if idx != 0:
            LONGITUDE = remaining_initial_seg_df.loc[idx, "longitude"]
            LATITUDE = remaining_initial_seg_df.loc[idx, "latitude"]
            current_coord = (LATITUDE, LONGITUDE)

            LONGITUDE = remaining_initial_seg_df.loc[idx - 1, "longitude"]
            LATITUDE = remaining_initial_seg_df.loc[idx - 1, "latitude"]
            previous_current_coord = (LATITUDE, LONGITUDE)
            
            accu_distance += haversine(current_coord, previous_current_coord, unit="km")
            
    duration_0 = cal_duration(km_h, accu_distance)
    duration_0 = duration_0 + init_duration
    
    
        
    dura_list = []  
    for next_seg_no in range(optimal_seg_no + 1, the_number_of_seg):
        next_seg_df = low_speed_df_list[next_seg_no]
        
        seg_mean_speed = next_seg_df['speed'].mean()
#         speed_damping_ratio = current_speed / seg_mean_speed
        speed_damping_ratio = 1
        damped_mean_speed = seg_mean_speed * speed_damping_ratio
        km_h = damped_mean_speed * 1.852
        distance = reckon_point_lengths(next_seg_df)
        dura_list.append(cal_duration(km_h, distance))
    
    accu_timedelta = datetime.timedelta(seconds=0)
    for i in dura_list:
        accu_timedelta += i
    # 현재 시간 + duration = ETA
    ETA = current_position_timestamp + accu_timedelta
    test_df_26.loc[col,'ETA'] = ETA
    optimal_seg_no = 0

test_df_26['ATA'] = test_df_26.loc[test_df_26.index[-1],"timestamp"]
test_df_26['error'] = abs(test_df_26['ATA'] - test_df_26['ETA'])

experiment_no = f"7.1.1.1_seg_{the_number_of_seg}_{cosco_fos_voy_number}".replace(".","_")
result_df_dict['experiment_no'].append(experiment_no)
result_df_dict['mean_speed'].append(test_df_26.loc[test_df_26.index[:-20]]["error"].mean())
result_df_dict['max_speed'].append(test_df_26.loc[test_df_26.index[:-20]]["error"].max())

globals()[f"exp_result_df_{experiment_no}"] = test_df_26

# %%
print("최대:", test_df_26.loc[test_df_26.index[:-20]]["error"].max())
print("평균:", test_df_26.loc[test_df_26.index[:-20]]["error"].mean())
# Out:
# 최대: 0 days 03:23:38.969961
# 평균: 0 days 01:31:30.577758432

# %%
test_df_26.loc[test_df_26['error'].dropna(axis=0).index].sort_values(by="error")
# Out:
#     vessel_name       mmsi        imo  CAPACITY destination       eta  \
# 244   COSCO FOS  477947700  9484302.0      4253       KRBNP  12160600
# 153   COSCO FOS  477947700  9484302.0      4253       KRBNP  12160200
# 246   COSCO FOS  477947700  9484302.0      4253       KRBNP  12160600
# 87    COSCO FOS  477947700  9484302.0      4253       KRBNP  12160200
# 248   COSCO FOS  477947700  9484302.0      4253       KRBNP  12160600
# ..          ...        ...        ...       ...         ...       ...
# 16    COSCO FOS  477947700  9484302.0      4253       KRBNP  12160600
# 19    COSCO FOS  477947700  9484302.0      4253       KRBNP  12160600
# 28    COSCO FOS  477947700  9484302.0      4253       KRBNP  12160600
# 17    COSCO FOS  477947700  9484302.0      4253       KRBNP  12160600
# 25    COSCO FOS  477947700  9484302.0      4253       KRBNP  12160600
#
#      longitude  latitude  speed  heading                  timestamp  \
# 244   128.6646   34.5345   15.1     58.0 2022-12-16 12:15:13.373409
# 153   125.8665   33.9484   11.7    116.0 2022-12-15 22:53:10.995659
# 246   128.7473   34.5857   14.7     52.0 2022-12-16 12:35:15.542395
# 87    124.7567   34.7987   14.9    155.0 2022-12-15 15:52:06.210774
# 248   128.8033   34.6297   10.8     12.0 2022-12-16 12:55:18.991172
# ..         ...       ...    ...      ...                        ...
# 16    118.3697   38.8214   10.3     97.0 2022-12-14 11:17:46.957298
# 19    118.5321   38.8100   13.6     95.0 2022-12-14 11:57:53.140221
# 28    118.7954   38.7829   13.7     99.0 2022-12-14 13:13:05.420521
# 17    118.4107   38.8178   10.3     95.0 2022-12-14 11:27:48.265208
# 25    118.7018   38.7952   13.7    100.0 2022-12-14 12:48:00.563693
#
#     time_position_data_received time_voyage_data_received  \
# 244  2022-12-16 03:13:28.000000       2022-12-16 03:13:06
# 153  2022-12-15 13:52:48.000000       2022-12-14 12:25:06
# 246  2022-12-16 03:33:58.000000       2022-12-16 03:13:06
# 87   2022-12-15 06:51:47.000000       2022-12-14 12:25:06
# 248  2022-12-16 03:50:49.000000       2022-12-16 03:37:06
# ..                          ...                       ...
# 16   2022-12-14 02:12:34.000000       2022-12-14 01:55:09
# 19   2022-12-14 02:54:05.000000       2022-12-14 02:25:10
# 28   2022-12-14 04:07:53.000000       2022-12-14 03:19:06
# 17   2022-12-14 02:23:45.000000       2022-12-14 02:25:10
# 25   2022-12-14 03:44:07.000000       2022-12-14 03:19:06
#
#             navigation_info  remained_distance  estimated_fuel_consumption  \
# 244  under way using engine          50.406951                    3.282647
# 153  under way using engine         293.569754                   15.939368
# 246  under way using engine          43.193408                    2.741423
# 87   under way using engine         371.042717                   23.852162
# 248  under way using engine          37.823964                    1.998419
# ..                      ...                ...                         ...
# 16   under way using engine        1022.360407                   53.504855
# 19   under way using engine        1008.818566                   59.936667
# 28   under way using engine         986.544062                   58.946401
# 17   under way using engine        1018.910058                   53.324282
# 25   under way using engine         994.569509                   59.425925
#
#                            ETA                        ATA  \
# 244 2022-12-16 15:15:41.058854 2022-12-16 15:15:40.309387
# 153 2022-12-16 15:16:42.857121 2022-12-16 15:15:40.309387
# 246 2022-12-16 15:14:26.222336 2022-12-16 15:15:40.309387
# 87  2022-12-16 15:17:04.070325 2022-12-16 15:15:40.309387
# 248 2022-12-16 15:13:17.816911 2022-12-16 15:15:40.309387
# ..                         ...                        ...
# 16  2022-12-16 18:19:17.619553 2022-12-16 15:15:40.309387
# 19  2022-12-16 18:23:01.114667 2022-12-16 15:15:40.309387
# 28  2022-12-16 18:25:56.334501 2022-12-16 15:15:40.309387
# 17  2022-12-16 18:29:18.927463 2022-12-16 15:15:40.309387
# 25  2022-12-16 18:39:19.279348 2022-12-16 15:15:40.309387
#
#                      error
# 244 0 days 00:00:00.749467
# 153 0 days 00:01:02.547734
# 246 0 days 00:01:14.087051
# 87  0 days 00:01:23.760938
# 248 0 days 00:02:22.492476
# ..                     ...
# 16  0 days 03:03:37.310166
# 19  0 days 03:07:20.805280
# 28  0 days 03:10:16.025114
# 17  0 days 03:13:38.618076
# 25  0 days 03:23:38.969961
#
# [251 rows x 19 columns]

# %% [markdown]
# ### 저속 (7knot 미만 포함)

# %% [markdown]
# #### 3. 순간 속력 이용 + 알고리즘 x  +  감속 계수 x

# %%
test_df_26 = pd.read_csv(f"voy_path/upper_china/processed/COSCO_FOS_VRKR6_2022_{cosco_fos_voy_number}processed.csv")
test_df_26['timestamp'] = pd.to_datetime(test_df_26['timestamp'])
test_df_26['timestamp'] = pd.to_datetime(test_df_26['timestamp'])
test_df_26['time_voyage_data_received'] = pd.to_datetime(test_df_26['time_voyage_data_received'])
test_df_26.drop('index', axis=1, inplace=True)
test_df_26 = test_df_26.loc[test_df_26[['longitude','latitude','timestamp']].drop_duplicates().index]
test_df_26.reset_index(inplace=True, drop=True)

# %%
for col in test_df_26.index:
    if col == test_df_26.index[-8]:
        break
    # 테스트 데이터
    re_sample = test_df_26.loc[col,:]
    longitude = re_sample["longitude"]
    latitude = re_sample["latitude"]
    current_point = (latitude, longitude)
    
    # 1. 순간 속력 (AIS) 
    current_speed = re_sample["speed"]
    current_position_timestamp = re_sample["timestamp"]
#     if current_speed < 7:
#         continue
    # 현재 위치에서 가장 짧은 segment 찾기
    shortest_distance = 9999
    for seg_no, seg_df in enumerate(low_speed_df_list):
        for idx in seg_df.index:
            LONGITUDE = seg_df.loc[idx, "longitude"]
            LATITUDE = seg_df.loc[idx, "latitude"]

            ais_point = (LATITUDE, LONGITUDE)
            distance = haversine(current_point, ais_point, unit="km")
            # 가장 짧은 segment 간의 거리, segment 번호, 인덱스 저장
            if distance <= shortest_distance:
                shortest_distance = distance 
                shortest_point_idx = seg_df.loc[idx, "index"]
                shortest_seg_no = seg_no
                
    # 다음 인덱스
#     optimal_point_idx = optimal_next_point(current_point, shortest_point_idx, shortest_distance, low_speed_interpolated_df)
    optimal_point_idx = low_speed_interpolated_df.query(f'index == {shortest_point_idx}').index[0] + 1
    lon_optimal = low_speed_interpolated_df.loc[optimal_point_idx, "longitude"]
    lat_optimal = low_speed_interpolated_df.loc[optimal_point_idx, "latitude"]
    
    optimal_point = (lat_optimal, lon_optimal)
    optimal_distance = haversine(current_point, optimal_point, unit="km")
    km_h = current_speed * 1.852
    init_duration = cal_duration(km_h, optimal_distance)
    
    
    # 가장 가까운 segment 찾기
    
    optimal_seg_no = find_segment_no(optimal_point_idx, low_speed_interpolated_df, the_number_of_seg)
    if optimal_seg_no == the_number_of_seg:
        continue
    initial_seg_df = low_speed_df_list[optimal_seg_no]
    # speed_damping_ratio는 각 segment에 맞게
#     speed_damping_ratio = current_speed / initial_seg_df["speed"].mean()
    speed_damping_ratio = 1
    km_h = current_speed * 1.852 * speed_damping_ratio
    
    
    remaining_initial_seg_df = initial_seg_df.loc[optimal_point_idx:,:]
    remaining_initial_seg_df.reset_index(inplace=True, drop=True)
    accu_distance = 0
    for idx in remaining_initial_seg_df.index:
        if idx != 0:
            LONGITUDE = remaining_initial_seg_df.loc[idx, "longitude"]
            LATITUDE = remaining_initial_seg_df.loc[idx, "latitude"]
            current_coord = (LATITUDE, LONGITUDE)

            LONGITUDE = remaining_initial_seg_df.loc[idx - 1, "longitude"]
            LATITUDE = remaining_initial_seg_df.loc[idx - 1, "latitude"]
            previous_current_coord = (LATITUDE, LONGITUDE)
            
            accu_distance += haversine(current_coord, previous_current_coord, unit="km")
            
    duration_0 = cal_duration(km_h, accu_distance)
    duration_0 = duration_0 + init_duration
    
    
        
    dura_list = []  
    for next_seg_no in range(optimal_seg_no + 1, the_number_of_seg):
        next_seg_df = low_speed_df_list[next_seg_no]
        
        seg_mean_speed = next_seg_df['speed'].mean()
#         speed_damping_ratio = current_speed / seg_mean_speed
        speed_damping_ratio = 1
        damped_mean_speed = seg_mean_speed * speed_damping_ratio
        km_h = damped_mean_speed * 1.852
        distance = reckon_point_lengths(next_seg_df)
        dura_list.append(cal_duration(km_h, distance))
    
    accu_timedelta = datetime.timedelta(seconds=0)
    for i in dura_list:
        accu_timedelta += i
    # 현재 시간 + duration = ETA
    ETA = current_position_timestamp + accu_timedelta
    test_df_26.loc[col,'ETA'] = ETA
    optimal_seg_no = 0

test_df_26['ATA'] = test_df_26.loc[test_df_26.index[-1],"timestamp"]
test_df_26['error'] = abs(test_df_26['ATA'] - test_df_26['ETA'])

experiment_no = f"7.1.2.1_seg_{the_number_of_seg}_{cosco_fos_voy_number}".replace(".","_")
result_df_dict['experiment_no'].append(experiment_no)
result_df_dict['mean_speed'].append(test_df_26.loc[test_df_26.index[:-20]]["error"].mean())
result_df_dict['max_speed'].append(test_df_26.loc[test_df_26.index[:-20]]["error"].max())

globals()[f"exp_result_df_{experiment_no}"] = test_df_26

# %%
print("최대:", test_df_26.loc[test_df_26.index[:-20]]["error"].max())
print("평균:", test_df_26.loc[test_df_26.index[:-20]]["error"].mean())
# Out:
# 최대: 0 days 03:23:38.969961
# 평균: 0 days 01:32:07.025769910

# %%
test_df_26.loc[test_df_26['error'].dropna(axis=0).index].sort_values(by="error")
# Out:
#     vessel_name       mmsi        imo  CAPACITY destination       eta  \
# 244   COSCO FOS  477947700  9484302.0      4253       KRBNP  12160600
# 153   COSCO FOS  477947700  9484302.0      4253       KRBNP  12160200
# 246   COSCO FOS  477947700  9484302.0      4253       KRBNP  12160600
# 87    COSCO FOS  477947700  9484302.0      4253       KRBNP  12160200
# 248   COSCO FOS  477947700  9484302.0      4253       KRBNP  12160600
# ..          ...        ...        ...       ...         ...       ...
# 16    COSCO FOS  477947700  9484302.0      4253       KRBNP  12160600
# 19    COSCO FOS  477947700  9484302.0      4253       KRBNP  12160600
# 28    COSCO FOS  477947700  9484302.0      4253       KRBNP  12160600
# 17    COSCO FOS  477947700  9484302.0      4253       KRBNP  12160600
# 25    COSCO FOS  477947700  9484302.0      4253       KRBNP  12160600
#
#      longitude  latitude  speed  heading                  timestamp  \
# 244   128.6646   34.5345   15.1     58.0 2022-12-16 12:15:13.373409
# 153   125.8665   33.9484   11.7    116.0 2022-12-15 22:53:10.995659
# 246   128.7473   34.5857   14.7     52.0 2022-12-16 12:35:15.542395
# 87    124.7567   34.7987   14.9    155.0 2022-12-15 15:52:06.210774
# 248   128.8033   34.6297   10.8     12.0 2022-12-16 12:55:18.991172
# ..         ...       ...    ...      ...                        ...
# 16    118.3697   38.8214   10.3     97.0 2022-12-14 11:17:46.957298
# 19    118.5321   38.8100   13.6     95.0 2022-12-14 11:57:53.140221
# 28    118.7954   38.7829   13.7     99.0 2022-12-14 13:13:05.420521
# 17    118.4107   38.8178   10.3     95.0 2022-12-14 11:27:48.265208
# 25    118.7018   38.7952   13.7    100.0 2022-12-14 12:48:00.563693
#
#     time_position_data_received time_voyage_data_received  \
# 244  2022-12-16 03:13:28.000000       2022-12-16 03:13:06
# 153  2022-12-15 13:52:48.000000       2022-12-14 12:25:06
# 246  2022-12-16 03:33:58.000000       2022-12-16 03:13:06
# 87   2022-12-15 06:51:47.000000       2022-12-14 12:25:06
# 248  2022-12-16 03:50:49.000000       2022-12-16 03:37:06
# ..                          ...                       ...
# 16   2022-12-14 02:12:34.000000       2022-12-14 01:55:09
# 19   2022-12-14 02:54:05.000000       2022-12-14 02:25:10
# 28   2022-12-14 04:07:53.000000       2022-12-14 03:19:06
# 17   2022-12-14 02:23:45.000000       2022-12-14 02:25:10
# 25   2022-12-14 03:44:07.000000       2022-12-14 03:19:06
#
#             navigation_info  remained_distance  estimated_fuel_consumption  \
# 244  under way using engine          50.406951                    3.282647
# 153  under way using engine         293.569754                   15.939368
# 246  under way using engine          43.193408                    2.741423
# 87   under way using engine         371.042717                   23.852162
# 248  under way using engine          37.823964                    1.998419
# ..                      ...                ...                         ...
# 16   under way using engine        1022.360407                   53.504855
# 19   under way using engine        1008.818566                   59.936667
# 28   under way using engine         986.544062                   58.946401
# 17   under way using engine        1018.910058                   53.324282
# 25   under way using engine         994.569509                   59.425925
#
#                            ETA                        ATA  \
# 244 2022-12-16 15:15:41.058854 2022-12-16 15:15:40.309387
# 153 2022-12-16 15:16:42.857121 2022-12-16 15:15:40.309387
# 246 2022-12-16 15:14:26.222336 2022-12-16 15:15:40.309387
# 87  2022-12-16 15:17:04.070325 2022-12-16 15:15:40.309387
# 248 2022-12-16 15:13:17.816911 2022-12-16 15:15:40.309387
# ..                         ...                        ...
# 16  2022-12-16 18:19:17.619553 2022-12-16 15:15:40.309387
# 19  2022-12-16 18:23:01.114667 2022-12-16 15:15:40.309387
# 28  2022-12-16 18:25:56.334501 2022-12-16 15:15:40.309387
# 17  2022-12-16 18:29:18.927463 2022-12-16 15:15:40.309387
# 25  2022-12-16 18:39:19.279348 2022-12-16 15:15:40.309387
#
#                      error
# 244 0 days 00:00:00.749467
# 153 0 days 00:01:02.547734
# 246 0 days 00:01:14.087051
# 87  0 days 00:01:23.760938
# 248 0 days 00:02:22.492476
# ..                     ...
# 16  0 days 03:03:37.310166
# 19  0 days 03:07:20.805280
# 28  0 days 03:10:16.025114
# 17  0 days 03:13:38.618076
# 25  0 days 03:23:38.969961
#
# [259 rows x 19 columns]

# %% [markdown]
# # ETA 실험 (interpolation 10000), COSCO FOS 30항차

# %%
cosco_fos_voy_number = "30"

# %% [markdown]
# ## segment 130

# %% [markdown]
# ### 저속 (7knot 미만 제거)

# %% [markdown]
# #### 3. 순간 속력 이용 + 알고리즘 x  +  감속 계수 x

# %%
test_df_26 = pd.read_csv(f"voy_path/upper_china/processed/COSCO_FOS_VRKR6_2022_{cosco_fos_voy_number}processed.csv")
test_df_26['timestamp'] = pd.to_datetime(test_df_26['timestamp'])
test_df_26['timestamp'] = pd.to_datetime(test_df_26['timestamp'])
test_df_26['time_voyage_data_received'] = pd.to_datetime(test_df_26['time_voyage_data_received'])
test_df_26.drop('index', axis=1, inplace=True)
test_df_26 = test_df_26.loc[test_df_26[['longitude','latitude','timestamp']].drop_duplicates().index]
test_df_26.reset_index(inplace=True, drop=True)

# %%
for col in test_df_26.index:
    if col == test_df_26.index[-8]:
        break
    # 테스트 데이터
    re_sample = test_df_26.loc[col,:]
    longitude = re_sample["longitude"]
    latitude = re_sample["latitude"]
    current_point = (latitude, longitude)
    
    # 1. 순간 속력 (AIS) 
    current_speed = re_sample["speed"]
    current_position_timestamp = re_sample["timestamp"]
    if current_speed < 7:
        continue
    # 현재 위치에서 가장 짧은 segment 찾기
    shortest_distance = 9999
    for seg_no, seg_df in enumerate(low_speed_df_list):
        for idx in seg_df.index:
            LONGITUDE = seg_df.loc[idx, "longitude"]
            LATITUDE = seg_df.loc[idx, "latitude"]

            ais_point = (LATITUDE, LONGITUDE)
            distance = haversine(current_point, ais_point, unit="km")
            # 가장 짧은 segment 간의 거리, segment 번호, 인덱스 저장
            if distance <= shortest_distance:
                shortest_distance = distance 
                shortest_point_idx = seg_df.loc[idx, "index"]
                shortest_seg_no = seg_no
                
    # 다음 인덱스
#     optimal_point_idx = optimal_next_point(current_point, shortest_point_idx, shortest_distance, low_speed_interpolated_df)
    optimal_point_idx = low_speed_interpolated_df.query(f'index == {shortest_point_idx}').index[0] + 1
    lon_optimal = low_speed_interpolated_df.loc[optimal_point_idx, "longitude"]
    lat_optimal = low_speed_interpolated_df.loc[optimal_point_idx, "latitude"]
    
    optimal_point = (lat_optimal, lon_optimal)
    optimal_distance = haversine(current_point, optimal_point, unit="km")
    km_h = current_speed * 1.852
    init_duration = cal_duration(km_h, optimal_distance)
    
    
    # 가장 가까운 segment 찾기
    
    optimal_seg_no = find_segment_no(optimal_point_idx, low_speed_interpolated_df, the_number_of_seg)
    if optimal_seg_no == the_number_of_seg:
        continue
    initial_seg_df = low_speed_df_list[optimal_seg_no]
    # speed_damping_ratio는 각 segment에 맞게
#     speed_damping_ratio = current_speed / initial_seg_df["speed"].mean()
    speed_damping_ratio = 1
    km_h = current_speed * 1.852 * speed_damping_ratio
    
    
    remaining_initial_seg_df = initial_seg_df.loc[optimal_point_idx:,:]
    remaining_initial_seg_df.reset_index(inplace=True, drop=True)
    accu_distance = 0
    for idx in remaining_initial_seg_df.index:
        if idx != 0:
            LONGITUDE = remaining_initial_seg_df.loc[idx, "longitude"]
            LATITUDE = remaining_initial_seg_df.loc[idx, "latitude"]
            current_coord = (LATITUDE, LONGITUDE)

            LONGITUDE = remaining_initial_seg_df.loc[idx - 1, "longitude"]
            LATITUDE = remaining_initial_seg_df.loc[idx - 1, "latitude"]
            previous_current_coord = (LATITUDE, LONGITUDE)
            
            accu_distance += haversine(current_coord, previous_current_coord, unit="km")
            
    duration_0 = cal_duration(km_h, accu_distance)
    duration_0 = duration_0 + init_duration
    
    
        
    dura_list = []  
    for next_seg_no in range(optimal_seg_no + 1, the_number_of_seg):
        next_seg_df = low_speed_df_list[next_seg_no]
        
        seg_mean_speed = next_seg_df['speed'].mean()
#         speed_damping_ratio = current_speed / seg_mean_speed
        speed_damping_ratio = 1
        damped_mean_speed = seg_mean_speed * speed_damping_ratio
        km_h = damped_mean_speed * 1.852
        distance = reckon_point_lengths(next_seg_df)
        dura_list.append(cal_duration(km_h, distance))
    
    accu_timedelta = datetime.timedelta(seconds=0)
    for i in dura_list:
        accu_timedelta += i
    # 현재 시간 + duration = ETA
    ETA = current_position_timestamp + accu_timedelta
    test_df_26.loc[col,'ETA'] = ETA
    optimal_seg_no = 0

test_df_26['ATA'] = test_df_26.loc[test_df_26.index[-1],"timestamp"]
test_df_26['error'] = abs(test_df_26['ATA'] - test_df_26['ETA'])

experiment_no = f"8.1.1.1_seg_{the_number_of_seg}_{cosco_fos_voy_number}".replace(".","_")
result_df_dict['experiment_no'].append(experiment_no)
result_df_dict['mean_speed'].append(test_df_26.loc[test_df_26.index[:-20]]["error"].mean())
result_df_dict['max_speed'].append(test_df_26.loc[test_df_26.index[:-20]]["error"].max())

globals()[f"exp_result_df_{experiment_no}"] = test_df_26

# %%
print("최대:", test_df_26.loc[test_df_26.index[:-20]]["error"].max())
print("평균:", test_df_26.loc[test_df_26.index[:-20]]["error"].mean())
# Out:
# 최대: 1 days 14:14:07.406722
# 평균: 1 days 09:18:39.639784128

# %%
test_df_26.loc[test_df_26['error'].dropna(axis=0).index].sort_values(by="error")
# Out:
#     vessel_name       mmsi        imo  CAPACITY destination       eta  \
# 455   COSCO FOS  477947700  9484302.0      4253       KRBNP  12260200
# 456   COSCO FOS  477947700  9484302.0      4253       KRBNP  12260200
# 435   COSCO FOS  477947700  9484302.0      4253       KRBNP  12260200
# 434   COSCO FOS  477947700  9484302.0      4253       KRBNP  12260200
# 433   COSCO FOS  477947700  9484302.0      4253       KRBNP  12260200
# ..          ...        ...        ...       ...         ...       ...
# 30    COSCO FOS  477947700  9484302.0      4253       KRBNP  12250200
# 26    COSCO FOS  477947700  9484302.0      4253       KRBNP  12250200
# 146   COSCO FOS  477947700  9484302.0      4253       KRBNP  12250200
# 34    COSCO FOS  477947700  9484302.0      4253       KRBNP  12250200
# 145   COSCO FOS  477947700  9484302.0      4253       KRBNP  12250200
#
#      longitude  latitude  speed  heading                  timestamp  \
# 455   128.9812   34.7568    7.4      6.0 2022-12-25 22:49:00.003814
# 456   128.9822   34.7785    7.8      0.0 2022-12-25 22:59:00.050255
# 435   128.9830   34.7741    7.0     38.0 2022-12-25 20:03:32.515081
# 434   128.9685   34.7620    7.3     41.0 2022-12-25 19:53:31.894087
# 433   128.9558   34.7514    7.6     41.0 2022-12-25 19:48:30.498043
# ..         ...       ...    ...      ...                        ...
# 30    120.6176   38.5989   14.1    103.0 2022-12-22 22:32:55.236631
# 26    120.4184   38.6281   14.8     99.0 2022-12-22 21:52:47.763379
# 146   125.2775   34.1388   10.8    112.0 2022-12-24 04:02:42.386260
# 34    120.7656   38.5722   14.4    104.0 2022-12-22 23:02:58.285550
# 145   125.2692   34.1424   10.4    113.0 2022-12-24 03:57:25.235441
#
#     time_position_data_received time_voyage_data_received  \
# 455  2022-12-25 13:48:15.000000       2022-12-25 01:48:28
# 456  2022-12-25 13:58:33.000000       2022-12-25 01:54:32
# 435  2022-12-25 11:01:14.000000       2022-12-25 10:54:29
# 434  2022-12-25 10:53:01.000000       2022-12-25 10:36:32
# 433  2022-12-25 10:45:54.000000       2022-12-25 10:36:32
# ..                          ...                       ...
# 30   2022-12-22 13:30:49.000000       2022-12-22 01:13:07
# 26   2022-12-22 12:50:57.000000       2022-12-22 12:49:08
# 146  2022-12-23 18:57:12.000000       2022-12-23 01:31:07
# 34   2022-12-22 14:01:25.000000       2022-12-22 02:01:06
# 145  2022-12-23 18:54:34.000000       2022-12-23 01:31:07
#
#             navigation_info  remained_distance  estimated_fuel_consumption  \
# 455  under way using engine          27.887166                    1.541612
# 456  under way using engine          25.922351                    1.403067
# 435  under way using engine          26.366358                    1.496521
# 434  under way using engine          26.791708                    1.490098
# 433  under way using engine          27.266309                    1.490517
# ..                      ...                ...                         ...
# 30   under way using engine         834.009393                   51.011507
# 26   under way using engine         850.972762                   54.354548
# 146  under way using engine         337.244859                   17.818243
# 34   under way using engine         821.175939                   51.150497
# 145  under way using engine         337.859918                   17.709129
#
#                            ETA                        ATA  \
# 455 2022-12-25 23:26:15.799193 2022-12-26 11:14:02.338182
# 456 2022-12-25 23:19:10.368191 2022-12-26 11:14:02.338182
# 435 2022-12-25 20:40:48.310460 2022-12-26 11:14:02.338182
# 434 2022-12-25 20:30:47.689466 2022-12-26 11:14:02.338182
# 433 2022-12-25 20:25:46.293422 2022-12-26 11:14:02.338182
# ..                         ...                        ...
# 30  2022-12-24 21:09:53.450717 2022-12-26 11:14:02.338182
# 26  2022-12-24 21:05:37.062981 2022-12-26 11:14:02.338182
# 146 2022-12-24 21:05:12.082279 2022-12-26 11:14:02.338182
# 34  2022-12-24 21:05:06.413664 2022-12-26 11:14:02.338182
# 145 2022-12-24 20:59:54.931460 2022-12-26 11:14:02.338182
#
#                      error
# 455 0 days 11:47:46.538989
# 456 0 days 11:54:51.969991
# 435 0 days 14:33:14.027722
# 434 0 days 14:43:14.648716
# 433 0 days 14:48:16.044760
# ..                     ...
# 30  1 days 14:04:08.887465
# 26  1 days 14:08:25.275201
# 146 1 days 14:08:50.255903
# 34  1 days 14:08:55.924518
# 145 1 days 14:14:07.406722
#
# [272 rows x 19 columns]

# %% [markdown]
# ### 저속 (7knot 미만 포함)

# %% [markdown]
# #### 3. 순간 속력 이용 + 알고리즘 x  +  감속 계수 x

# %%
test_df_26 = pd.read_csv(f"voy_path/upper_china/processed/COSCO_FOS_VRKR6_2022_{cosco_fos_voy_number}processed.csv")
test_df_26['timestamp'] = pd.to_datetime(test_df_26['timestamp'])
test_df_26['timestamp'] = pd.to_datetime(test_df_26['timestamp'])
test_df_26['time_voyage_data_received'] = pd.to_datetime(test_df_26['time_voyage_data_received'])
test_df_26.drop('index', axis=1, inplace=True)
test_df_26 = test_df_26.loc[test_df_26[['longitude','latitude','timestamp']].drop_duplicates().index]
test_df_26.reset_index(inplace=True, drop=True)

# %%
for col in test_df_26.index:
    if col == test_df_26.index[-8]:
        break
    # 테스트 데이터
    re_sample = test_df_26.loc[col,:]
    longitude = re_sample["longitude"]
    latitude = re_sample["latitude"]
    current_point = (latitude, longitude)
    
    # 1. 순간 속력 (AIS) 
    current_speed = re_sample["speed"]
    current_position_timestamp = re_sample["timestamp"]
#     if current_speed < 7:
#         continue
    # 현재 위치에서 가장 짧은 segment 찾기
    shortest_distance = 9999
    for seg_no, seg_df in enumerate(low_speed_df_list):
        for idx in seg_df.index:
            LONGITUDE = seg_df.loc[idx, "longitude"]
            LATITUDE = seg_df.loc[idx, "latitude"]

            ais_point = (LATITUDE, LONGITUDE)
            distance = haversine(current_point, ais_point, unit="km")
            # 가장 짧은 segment 간의 거리, segment 번호, 인덱스 저장
            if distance <= shortest_distance:
                shortest_distance = distance 
                shortest_point_idx = seg_df.loc[idx, "index"]
                shortest_seg_no = seg_no
                
    # 다음 인덱스
#     optimal_point_idx = optimal_next_point(current_point, shortest_point_idx, shortest_distance, low_speed_interpolated_df)
    optimal_point_idx = low_speed_interpolated_df.query(f'index == {shortest_point_idx}').index[0] + 1
    lon_optimal = low_speed_interpolated_df.loc[optimal_point_idx, "longitude"]
    lat_optimal = low_speed_interpolated_df.loc[optimal_point_idx, "latitude"]
    
    optimal_point = (lat_optimal, lon_optimal)
    optimal_distance = haversine(current_point, optimal_point, unit="km")
    km_h = current_speed * 1.852
    init_duration = cal_duration(km_h, optimal_distance)
    
    
    # 가장 가까운 segment 찾기
    
    optimal_seg_no = find_segment_no(optimal_point_idx, low_speed_interpolated_df, the_number_of_seg)
    if optimal_seg_no == the_number_of_seg:
        continue
    initial_seg_df = low_speed_df_list[optimal_seg_no]
    # speed_damping_ratio는 각 segment에 맞게
#     speed_damping_ratio = current_speed / initial_seg_df["speed"].mean()
    speed_damping_ratio = 1
    km_h = current_speed * 1.852 * speed_damping_ratio
    
    
    remaining_initial_seg_df = initial_seg_df.loc[optimal_point_idx:,:]
    remaining_initial_seg_df.reset_index(inplace=True, drop=True)
    accu_distance = 0
    for idx in remaining_initial_seg_df.index:
        if idx != 0:
            LONGITUDE = remaining_initial_seg_df.loc[idx, "longitude"]
            LATITUDE = remaining_initial_seg_df.loc[idx, "latitude"]
            current_coord = (LATITUDE, LONGITUDE)

            LONGITUDE = remaining_initial_seg_df.loc[idx - 1, "longitude"]
            LATITUDE = remaining_initial_seg_df.loc[idx - 1, "latitude"]
            previous_current_coord = (LATITUDE, LONGITUDE)
            
            accu_distance += haversine(current_coord, previous_current_coord, unit="km")
            
    duration_0 = cal_duration(km_h, accu_distance)
    duration_0 = duration_0 + init_duration
    
    
        
    dura_list = []  
    for next_seg_no in range(optimal_seg_no + 1, the_number_of_seg):
        next_seg_df = low_speed_df_list[next_seg_no]
        
        seg_mean_speed = next_seg_df['speed'].mean()
#         speed_damping_ratio = current_speed / seg_mean_speed
        speed_damping_ratio = 1
        damped_mean_speed = seg_mean_speed * speed_damping_ratio
        km_h = damped_mean_speed * 1.852
        distance = reckon_point_lengths(next_seg_df)
        dura_list.append(cal_duration(km_h, distance))
    
    accu_timedelta = datetime.timedelta(seconds=0)
    for i in dura_list:
        accu_timedelta += i
    # 현재 시간 + duration = ETA
    ETA = current_position_timestamp + accu_timedelta
    test_df_26.loc[col,'ETA'] = ETA
    optimal_seg_no = 0

test_df_26['ATA'] = test_df_26.loc[test_df_26.index[-1],"timestamp"]
test_df_26['error'] = abs(test_df_26['ATA'] - test_df_26['ETA'])

experiment_no = f"8.1.2.1_seg_{the_number_of_seg}_{cosco_fos_voy_number}".replace(".","_")
result_df_dict['experiment_no'].append(experiment_no)
result_df_dict['mean_speed'].append(test_df_26.loc[test_df_26.index[:-20]]["error"].mean())
result_df_dict['max_speed'].append(test_df_26.loc[test_df_26.index[:-20]]["error"].max())

globals()[f"exp_result_df_{experiment_no}"] = test_df_26

# %%
print("최대:", test_df_26.loc[test_df_26.index[:-20]]["error"].max())
print("평균:", test_df_26.loc[test_df_26.index[:-20]]["error"].mean())
# Out:
# 최대: 1 days 14:14:07.406722
# 평균: 1 days 01:51:07.710827706

# %%
test_df_26.loc[test_df_26['error'].dropna(axis=0).index].sort_values(by="error")
# Out:
#     vessel_name       mmsi        imo  CAPACITY destination       eta  \
# 539   COSCO FOS  477947700  9484302.0      4253       KRBNP  12260200
# 538   COSCO FOS  477947700  9484302.0      4253       KRBNP  12260200
# 537   COSCO FOS  477947700  9484302.0      4253       KRBNP  12260200
# 535   COSCO FOS  477947700  9484302.0      4253       KRBNP  12260200
# 536   COSCO FOS  477947700  9484302.0      4253       KRBNP  12260200
# ..          ...        ...        ...       ...         ...       ...
# 30    COSCO FOS  477947700  9484302.0      4253       KRBNP  12250200
# 26    COSCO FOS  477947700  9484302.0      4253       KRBNP  12250200
# 146   COSCO FOS  477947700  9484302.0      4253       KRBNP  12250200
# 34    COSCO FOS  477947700  9484302.0      4253       KRBNP  12250200
# 145   COSCO FOS  477947700  9484302.0      4253       KRBNP  12250200
#
#      longitude  latitude  speed  heading                  timestamp  \
# 539   128.8677   34.7970    4.0      5.0 2022-12-26 09:53:49.419733
# 538   128.8675   34.7935    3.1      9.0 2022-12-26 09:48:49.140018
# 537   128.8696   34.7895    1.0    359.0 2022-12-26 09:43:47.628816
# 535   128.8696   34.7743    5.1      9.0 2022-12-26 09:23:45.094683
# 536   128.8700   34.7848    3.4      9.0 2022-12-26 09:28:45.105970
# ..         ...       ...    ...      ...                        ...
# 30    120.6176   38.5989   14.1    103.0 2022-12-22 22:32:55.236631
# 26    120.4184   38.6281   14.8     99.0 2022-12-22 21:52:47.763379
# 146   125.2775   34.1388   10.8    112.0 2022-12-24 04:02:42.386260
# 34    120.7656   38.5722   14.4    104.0 2022-12-22 23:02:58.285550
# 145   125.2692   34.1424   10.4    113.0 2022-12-24 03:57:25.235441
#
#     time_position_data_received time_voyage_data_received  \
# 539  2022-12-26 00:51:22.000000       2022-12-26 12:36:30
# 538  2022-12-26 00:47:51.000000       2022-12-26 12:36:30
# 537  2022-12-26 00:35:30.000000       2022-12-26 12:36:30
# 535  2022-12-26 00:19:50.000000       2022-12-26 12:06:29
# 536  2022-12-26 00:27:43.000000       2022-12-26 12:06:29
# ..                          ...                       ...
# 30   2022-12-22 13:30:49.000000       2022-12-22 01:13:07
# 26   2022-12-22 12:50:57.000000       2022-12-22 12:49:08
# 146  2022-12-23 18:57:12.000000       2022-12-23 01:31:07
# 34   2022-12-22 14:01:25.000000       2022-12-22 02:01:06
# 145  2022-12-23 18:54:34.000000       2022-12-23 01:31:07
#
#             navigation_info  remained_distance  estimated_fuel_consumption  \
# 539  under way using engine          19.690436                    1.696165
# 538  under way using engine          20.065989                    2.188481
# 537  under way using engine          20.542092                    6.833451
# 535  under way using engine          22.193092                    1.555887
# 536  under way using engine          21.059894                    2.105354
# ..                      ...                ...                         ...
# 30   under way using engine         834.009393                   51.011507
# 26   under way using engine         850.972762                   54.354548
# 146  under way using engine         337.244859                   17.818243
# 34   under way using engine         821.175939                   51.150497
# 145  under way using engine         337.859918                   17.709129
#
#                            ETA                        ATA  \
# 539 2022-12-26 10:13:59.737669 2022-12-26 11:14:02.338182
# 538 2022-12-26 10:08:59.457954 2022-12-26 11:14:02.338182
# 537 2022-12-26 10:03:57.946752 2022-12-26 11:14:02.338182
# 535 2022-12-26 10:01:00.890062 2022-12-26 11:14:02.338182
# 536 2022-12-26 09:48:55.423906 2022-12-26 11:14:02.338182
# ..                         ...                        ...
# 30  2022-12-24 21:09:53.450717 2022-12-26 11:14:02.338182
# 26  2022-12-24 21:05:37.062981 2022-12-26 11:14:02.338182
# 146 2022-12-24 21:05:12.082279 2022-12-26 11:14:02.338182
# 34  2022-12-24 21:05:06.413664 2022-12-26 11:14:02.338182
# 145 2022-12-24 20:59:54.931460 2022-12-26 11:14:02.338182
#
#                      error
# 539 0 days 01:00:02.600513
# 538 0 days 01:05:02.880228
# 537 0 days 01:10:04.391430
# 535 0 days 01:13:01.448120
# 536 0 days 01:25:06.914276
# ..                     ...
# 30  1 days 14:04:08.887465
# 26  1 days 14:08:25.275201
# 146 1 days 14:08:50.255903
# 34  1 days 14:08:55.924518
# 145 1 days 14:14:07.406722
#
# [540 rows x 19 columns]

# %% [markdown]
# # 결과 확인

# %%
result_pool = pd.DataFrame(result_df_dict)
result_pool
# Out:
#         experiment_no                mean_speed              max_speed
# 0  4_1_1_1_seg_130_20 1 days 01:57:29.464779090 1 days 14:30:24.308333
# 1  4_1_2_1_seg_130_20 1 days 00:21:13.972728923 1 days 14:30:24.308333
# 2  5_1_1_1_seg_130_24 0 days 01:01:48.595966014 0 days 02:16:02.628344
# 3  5_1_2_1_seg_130_24 0 days 01:01:01.838284289 0 days 02:16:02.628344
# 4  6_1_1_1_seg_130_28 0 days 23:31:12.763457590 2 days 00:28:15.525331
# 5  6_1_2_1_seg_130_28 0 days 21:05:55.070685982 2 days 00:33:18.515470
# 6  7_1_1_1_seg_130_29 0 days 01:31:30.577758432 0 days 03:23:38.969961
# 7  7_1_2_1_seg_130_29 0 days 01:32:07.025769910 0 days 03:23:38.969961
# 8  8_1_1_1_seg_130_30 1 days 09:18:39.639784128 1 days 14:14:07.406722
# 9  8_1_2_1_seg_130_30 1 days 01:51:07.710827706 1 days 14:14:07.406722

# %%
result_pool.sort_values(by="mean_speed")
# Out:
#         experiment_no                mean_speed              max_speed
# 3  5_1_2_1_seg_130_24 0 days 01:01:01.838284289 0 days 02:16:02.628344
# 2  5_1_1_1_seg_130_24 0 days 01:01:48.595966014 0 days 02:16:02.628344
# 6  7_1_1_1_seg_130_29 0 days 01:31:30.577758432 0 days 03:23:38.969961
# 7  7_1_2_1_seg_130_29 0 days 01:32:07.025769910 0 days 03:23:38.969961
# 5  6_1_2_1_seg_130_28 0 days 21:05:55.070685982 2 days 00:33:18.515470
# 4  6_1_1_1_seg_130_28 0 days 23:31:12.763457590 2 days 00:28:15.525331
# 1  4_1_2_1_seg_130_20 1 days 00:21:13.972728923 1 days 14:30:24.308333
# 9  8_1_2_1_seg_130_30 1 days 01:51:07.710827706 1 days 14:14:07.406722
# 0  4_1_1_1_seg_130_20 1 days 01:57:29.464779090 1 days 14:30:24.308333
# 8  8_1_1_1_seg_130_30 1 days 09:18:39.639784128 1 days 14:14:07.406722

# %%
result_pool.to_csv(f"230130_result_pool_interpolation_{interpolation_number}_segment_100_cosco_fos_low_speed_voyages.csv", encoding="utf-8 sig", header=True, index=False)

# %%
for i in globals():
    if 'exp_result_df_' in i:
        print(i)
        globals()[i].to_csv(f"실험/230130_{i}", encoding="utf-8 sig", header=True, index=False)
# Out:
# exp_result_df_4_1_1_1_seg_130_20
# exp_result_df_4_1_2_1_seg_130_20
# exp_result_df_5_1_1_1_seg_130_24
# exp_result_df_5_1_2_1_seg_130_24
# exp_result_df_6_1_1_1_seg_130_28
# exp_result_df_6_1_2_1_seg_130_28
# exp_result_df_7_1_1_1_seg_130_29
# exp_result_df_7_1_2_1_seg_130_29
# exp_result_df_8_1_1_1_seg_130_30
# exp_result_df_8_1_2_1_seg_130_30
